# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
from place_groups import place_groups_middle_of_roads, place_groups_junctions

from sklearn.linear_model import LinearRegression
from datetime import timedelta
from keras.callbacks import ModelCheckpoint
import numpy as np
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import pandas as pd
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers.recurrent import LSTM
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras.layers import BatchNormalization
from keras.models import Sequential
from keras import regularizers

from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
# Out:
# Using TensorFlow backend.

# %%
HDF5_PREFIX = 'only_speed_lstm_simple'

# %%
HDF5_DIR = os.path.join('.', 'hdf5')
ONE_DAY_LAGS = 288
DATA_PATH = '/mnt/sdc1/inon/norrecampus/data/by_place_5min'
EXAMPLE_PLACE_ID = 'ChIJZaR1M1hSUkYRxP0WkwYYy_k'

THRESHOLD_HIGH_OUTLIER = 110
LOSS = 'mse'
MINI_BATCH_SIZE = 512
NUM_EPOCHS = 100
VALIDATION_SPLIT = 0.2
NUM_LAGS = 12
LSTM_STATE_SIZE = NUM_LAGS
NUM_OUTS_MEAN_SPEED_REGRESSION = 1
SPLIT_DATE = '2015-06-01'

# %%
def split_timestamp(ser):
    return pd\
        .DataFrame(ser)\
        .assign(day_of_week=lambda df: df.index.dayofweek, time_of_day=lambda df: df.index.time)\
        .reset_index()

# %%
class LearnerForMeanSpeedOfOneSegment(object):
    def __init__(self,
                 threshold_high_outlier,
                 loss,
                 place_id, 
                 mini_batch_size,
                 num_epochs,
                 validation_split,
                 num_lags,
                 lstm_state_size,
                 num_outs,
                 split_date):
        self.df = None
        self.model = None
        
        self.threshold_high_outlier = threshold_high_outlier
        self.loss = loss
        self.place_id = place_id
        self.mini_batch_size = mini_batch_size
        self.num_epochs = num_epochs
        self.validation_split = validation_split
        self.num_lags = num_lags
        self.lstm_state_size = lstm_state_size
        self.num_outs = num_outs
        self.split_date = split_date
        self.checkpoint_basename = os.path.join(HDF5_DIR, '%s_%s.best.hdf5' % (HDF5_PREFIX, self.place_id))
    
    def compute_error_statistics(self, errors_df):
        abs_errors = errors_df.error.abs()
        abs_errors_normalized = abs_errors / errors_df.speed_km_hr_true
        return pd.DataFrame({
            'corr': np.corrcoef(errors_df.speed_km_hr_predicted, errors_df.speed_km_hr_true)[0, 1],
            'mae': np.mean(abs_errors),
            'mape': np.mean(abs_errors_normalized),
            'mse': np.mean(abs_errors ** 2),
            'msne': np.mean(abs_errors_normalized ** 2),
            'rae': np.sum(abs_errors) / np.sum(np.abs(errors_df.speed_km_hr_true - np.mean(errors_df.speed_km_hr_true))),
            'rmse': np.sqrt(np.mean(abs_errors ** 2)),
            'rmsne': np.sqrt(np.mean(abs_errors_normalized ** 2)),
            'r2': max(0, 1 - np.sum(abs_errors ** 2) / np.sum((errors_df.speed_km_hr_true - np.mean(errors_df.speed_km_hr_true)) ** 2))
        }, index=[self.place_id])
    
    def baseline_lr(self):
        X_train_normalized, Y_train_normalized, X_test_normalized, Y_test_normalized = self._get_train_and_test_inputs()
        trained_lr = LinearRegression(fit_intercept=False).fit(X_train_normalized.values, Y_train_normalized.values)
        lr_predictions_normalized = trained_lr.predict(X_test_normalized)
        errors_df = self._individual_errors_without_interpolated_values(lr_predictions_normalized)
        return self.compute_error_statistics(errors_df)
        
    def _get_detrend_factors(self):
        ser_imp = self._imputation_for_missing_values_and_outliers(self._get_df()).speed_km_hr
        df_train_period = ser_imp[lambda df: df.index < self.split_date]
        return df_train_period\
            .groupby([df_train_period.index.dayofweek, df_train_period.index.time])\
            .agg(['mean', 'std'])\
            .reset_index()\
            .rename(columns={'level_0': 'day_of_week', 'level_1': 'time_of_day'})
        
    def detrend(self, ser):
        return pd\
            .merge(left=split_timestamp(ser), 
                   right=self._get_detrend_factors(),
                   on=['day_of_week', 'time_of_day'], 
                   how='inner')\
                .assign(speed_normalized=lambda df: (df.speed_km_hr - df['mean']) / df['std'])\
                .set_index('index')\
                .speed_normalized\
                .sort_index()

    def _map_back(self, detrended_series):
        return pd\
            .merge(left=split_timestamp(detrended_series), 
                   right=self._get_detrend_factors(),
                   on=['day_of_week', 'time_of_day'], 
                   how='inner')\
            .assign(speed_km_hr=lambda df: (df.speed_normalized * df['std']) + df['mean'])\
            .set_index('index')\
            .speed_km_hr\
            .sort_index()
    
    def _imputation_for_missing_values_and_outliers(self, ser):
        missing_timestamps = pd\
            .date_range(min(ser.index.date), max(ser.index.date) + timedelta(days=1), freq='5T')\
            .difference(ser.index)
        df_with_nans_where_missing = pd.DataFrame(ser)\
            .join(pd.DataFrame(index=missing_timestamps), how='outer')\
            .assign(original_value=lambda df: df.iloc[:, 0])
        return df_with_nans_where_missing\
            .iloc[:, 0]\
            .mask(lambda df: df > self.threshold_high_outlier)\
            .interpolate()\
            .to_frame()\
            .assign(original_value=df_with_nans_where_missing.original_value)\
            .assign(is_interpolated=lambda df: df.iloc[:, 0] != df.iloc[:, 1])
        
    def _get_df(self):
        if self.df is None:
            self.df = pd.read_csv(
                os.path.join(DATA_PATH, self.place_id + '.csv'),
                parse_dates=['start_interval_s', 'end_interval_s']\
            )[lambda df: df.start_interval_s >= '2015-01-01']\
            .rename(columns={'start_interval_s': 't', 'speed_mean': 'speed_km_hr'})\
            .set_index('t')\
            .speed_km_hr
        return self.df

    def _get_train_and_test_inputs(self):
        speeds_interpolated_and_detrended = self.detrend(
            self._imputation_for_missing_values_and_outliers(self._get_df()).speed_km_hr)
        lags = pd.concat([speeds_interpolated_and_detrended.shift(x) for x in range(self.num_lags + 1)], axis=1)[self.num_lags:]
        train = lags[lags.index < self.split_date]
        X_train = train.iloc[:, 1:]
        Y_train = train.iloc[:, 0]
        test = lags[lags.index >= self.split_date]
        X_test = test.iloc[:, 1:]
        Y_test = test.iloc[:, 0]
        return X_train, Y_train, X_test, Y_test

    def _build_model(self):
        # TODO: better weights initialization
        self.model = Sequential()
        self.model.add(LSTM(self.lstm_state_size, input_shape=(self.num_lags, 1), return_sequences=False))
        # model.add(Dropout(0.2))
        #model.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.00001)))
        self.model.add(Dense(units=self.num_outs, activation="linear"))  # Linear activation, because speed RESIDUALS can have any sign.
        self.model.compile(loss=self.loss, optimizer="rmsprop")  # TODO: try adam optimizer too, although rmsprop is the default go-to for RNN
    
    def load_best_model_from_disk(self):
        self._build_model()
        self.model.load_weights(self.checkpoint_basename)
    
    def create_and_train_model(self):
        self._build_model()
        X_train, Y_train, _, _ = self._get_train_and_test_inputs()
        self.model.fit(
            np.expand_dims(np.array(X_train.values), 2),
            Y_train.values,
            batch_size=self.mini_batch_size,
            epochs=self.num_epochs,
            validation_split=self.validation_split,
            # checkpoint best model
            callbacks=[ModelCheckpoint(
                self.checkpoint_basename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')],
            verbose=2)
        self.model.load_weights(self.checkpoint_basename)
    
    def predict(self):
        _, _, X_test_normalized, Y_test_normalized = self._get_train_and_test_inputs()
        predictions_normalized = self.model.predict(np.expand_dims(X_test_normalized, 2)).flatten()
        errors_df = self._individual_errors_without_interpolated_values(predictions_normalized)
        return self.compute_error_statistics(errors_df)
        
    def _impute(self):
        raise NotImplementedError
        
    def _individual_errors_without_interpolated_values(self, predictions_normalized):
        _, _, _, Y_test_normalized = self._get_train_and_test_inputs()
        ser_Y_test = self._map_back(Y_test_normalized)
        ser_predictions = self._map_back(pd.Series(
            predictions_normalized, index=Y_test_normalized.index, name='speed_normalized'))
        interpolated_timestamps = self\
            ._imputation_for_missing_values_and_outliers(self._get_df())\
            [lambda df: df.is_interpolated]\
            .index
        return ser_Y_test.to_frame()\
            .join(ser_predictions.to_frame(), lsuffix='_true', rsuffix='_predicted')\
            .loc[lambda df: df.index.difference(interpolated_timestamps)]\
            .assign(error=lambda df: df.speed_km_hr_true - df.speed_km_hr_predicted)

# %%
def one_place_improvement_over_baseline_lr(place_id):
    learner = LearnerForMeanSpeedOfOneSegment(
        threshold_high_outlier=THRESHOLD_HIGH_OUTLIER,
        loss=LOSS,
        place_id=place_id, 
        mini_batch_size=MINI_BATCH_SIZE,
        num_epochs=NUM_EPOCHS,
        validation_split=VALIDATION_SPLIT,
        num_lags=NUM_LAGS,
        lstm_state_size=LSTM_STATE_SIZE,
        num_outs=NUM_OUTS_MEAN_SPEED_REGRESSION,
        split_date=SPLIT_DATE)
    learner.create_and_train_model()
    learner.load_best_model_from_disk()
    return learner.predict() - learner.baseline_lr()

# %%
# one_place_improvement_over_baseline_lr(EXAMPLE_PLACE_ID)

# %%
def multiple_places(place_group, place_group_name):
    places = [lst[len(lst) // 2] for lst in place_group]
    return pd.concat(map(one_place_improvement_over_baseline_lr, places))\
        .to_csv('%s_improvement_over_baseline_lr_v1.csv' % place_group_name)

# %%
multiple_places(place_groups_middle_of_roads, 'place_groups_middle_of_roads')
# Out:
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 0.76010, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 2s - loss: 0.9336 - val_loss: 0.7601
# Epoch 2/100
# Epoch 00002: val_loss improved from 0.76010 to 0.64227, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.8083 - val_loss: 0.6423
# Epoch 3/100
# Epoch 00003: val_loss improved from 0.64227 to 0.53455, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.6728 - val_loss: 0.5346
# Epoch 4/100
# Epoch 00004: val_loss improved from 0.53455 to 0.46829, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.5725 - val_loss: 0.4683
# Epoch 5/100
# Epoch 00005: val_loss improved from 0.46829 to 0.42656, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.5126 - val_loss: 0.4266
# Epoch 6/100
# Epoch 00006: val_loss improved from 0.42656 to 0.41521, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.4731 - val_loss: 0.4152
# Epoch 7/100
# Epoch 00007: val_loss improved from 0.41521 to 0.37836, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.4455 - val_loss: 0.3784
# Epoch 8/100
# Epoch 00008: val_loss improved from 0.37836 to 0.35740, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.4239 - val_loss: 0.3574
# Epoch 9/100
# Epoch 00009: val_loss improved from 0.35740 to 0.34393, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.4102 - val_loss: 0.3439
# Epoch 10/100
# Epoch 00010: val_loss improved from 0.34393 to 0.33155, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.4012 - val_loss: 0.3315
# Epoch 11/100
# Epoch 00011: val_loss improved from 0.33155 to 0.32570, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3949 - val_loss: 0.3257
# Epoch 12/100
# Epoch 00012: val_loss did not improve
#  - 1s - loss: 0.3851 - val_loss: 0.3506
# Epoch 13/100
# Epoch 00013: val_loss did not improve
#  - 1s - loss: 0.3788 - val_loss: 0.3788
# Epoch 14/100
# Epoch 00014: val_loss did not improve
#  - 1s - loss: 0.3728 - val_loss: 0.3356
# Epoch 15/100
# Epoch 00015: val_loss did not improve
#  - 1s - loss: 0.3661 - val_loss: 0.3343
# Epoch 16/100
# Epoch 00016: val_loss improved from 0.32570 to 0.31946, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3597 - val_loss: 0.3195
# Epoch 17/100
# Epoch 00017: val_loss improved from 0.31946 to 0.30008, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3584 - val_loss: 0.3001
# Epoch 18/100
# Epoch 00018: val_loss did not improve
#  - 1s - loss: 0.3504 - val_loss: 0.3707
# Epoch 19/100
# Epoch 00019: val_loss improved from 0.30008 to 0.28717, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3482 - val_loss: 0.2872
# Epoch 20/100
# Epoch 00020: val_loss did not improve
#  - 1s - loss: 0.3446 - val_loss: 0.3123
# Epoch 21/100
# Epoch 00021: val_loss did not improve
#  - 1s - loss: 0.3385 - val_loss: 0.4087
# Epoch 22/100
# Epoch 00022: val_loss improved from 0.28717 to 0.28074, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3364 - val_loss: 0.2807
# Epoch 23/100
# Epoch 00023: val_loss did not improve
#  - 1s - loss: 0.3320 - val_loss: 0.2932
# Epoch 24/100
# Epoch 00024: val_loss did not improve
#  - 1s - loss: 0.3323 - val_loss: 0.2955
# Epoch 25/100
# Epoch 00025: val_loss did not improve
#  - 1s - loss: 0.3266 - val_loss: 0.3365
# Epoch 26/100
# Epoch 00026: val_loss did not improve
#  - 1s - loss: 0.3270 - val_loss: 0.2951
# Epoch 27/100
# Epoch 00027: val_loss improved from 0.28074 to 0.28068, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3253 - val_loss: 0.2807
# Epoch 28/100
# Epoch 00028: val_loss improved from 0.28068 to 0.27117, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3209 - val_loss: 0.2712
# Epoch 29/100
# Epoch 00029: val_loss did not improve
#  - 1s - loss: 0.3190 - val_loss: 0.3074
# Epoch 30/100
# Epoch 00030: val_loss improved from 0.27117 to 0.26070, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3165 - val_loss: 0.2607
# Epoch 31/100
# Epoch 00031: val_loss improved from 0.26070 to 0.25964, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3161 - val_loss: 0.2596
# Epoch 32/100
# Epoch 00032: val_loss did not improve
#  - 1s - loss: 0.3142 - val_loss: 0.2837
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 1s - loss: 0.3130 - val_loss: 0.2975
# Epoch 34/100
# Epoch 00034: val_loss did not improve
#  - 1s - loss: 0.3133 - val_loss: 0.2763
# Epoch 35/100
# Epoch 00035: val_loss did not improve
#  - 1s - loss: 0.3096 - val_loss: 0.2862
# Epoch 36/100
# Epoch 00036: val_loss did not improve
#  - 1s - loss: 0.3085 - val_loss: 0.2834
# Epoch 37/100
# Epoch 00037: val_loss improved from 0.25964 to 0.25157, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3065 - val_loss: 0.2516
# Epoch 38/100
# Epoch 00038: val_loss improved from 0.25157 to 0.24948, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3065 - val_loss: 0.2495
# Epoch 39/100
# Epoch 00039: val_loss improved from 0.24948 to 0.24834, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.3046 - val_loss: 0.2483
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 1s - loss: 0.3024 - val_loss: 0.2555
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 1s - loss: 0.3022 - val_loss: 0.2630
# Epoch 42/100
# Epoch 00042: val_loss did not improve
#  - 1s - loss: 0.3014 - val_loss: 0.2561
# Epoch 43/100
# Epoch 00043: val_loss did not improve
#  - 1s - loss: 0.2997 - val_loss: 0.2566
# Epoch 44/100
# Epoch 00044: val_loss did not improve
#  - 1s - loss: 0.2971 - val_loss: 0.3062
# Epoch 45/100
# Epoch 00045: val_loss improved from 0.24834 to 0.24506, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2993 - val_loss: 0.2451
# Epoch 46/100
# Epoch 00046: val_loss did not improve
#  - 1s - loss: 0.2945 - val_loss: 0.2763
# Epoch 47/100
# Epoch 00047: val_loss did not improve
#  - 1s - loss: 0.2972 - val_loss: 0.2661
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 1s - loss: 0.2929 - val_loss: 0.2739
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 1s - loss: 0.2941 - val_loss: 0.2560
# Epoch 50/100
# Epoch 00050: val_loss improved from 0.24506 to 0.24406, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2923 - val_loss: 0.2441
# Epoch 51/100
# Epoch 00051: val_loss improved from 0.24406 to 0.23756, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2931 - val_loss: 0.2376
# Epoch 52/100
# Epoch 00052: val_loss did not improve
#  - 1s - loss: 0.2917 - val_loss: 0.2682
# Epoch 53/100
# Epoch 00053: val_loss did not improve
#  - 1s - loss: 0.2880 - val_loss: 0.2474
# Epoch 54/100
# Epoch 00054: val_loss did not improve
#  - 1s - loss: 0.2888 - val_loss: 0.2394
# Epoch 55/100
# Epoch 00055: val_loss did not improve
#  - 1s - loss: 0.2893 - val_loss: 0.2499
# Epoch 56/100
# Epoch 00056: val_loss did not improve
#  - 1s - loss: 0.2872 - val_loss: 0.3074
# Epoch 57/100
# Epoch 00057: val_loss did not improve
#  - 1s - loss: 0.2866 - val_loss: 0.2480
# Epoch 58/100
# Epoch 00058: val_loss did not improve
#  - 1s - loss: 0.2859 - val_loss: 0.2418
# Epoch 59/100
# Epoch 00059: val_loss improved from 0.23756 to 0.23402, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2869 - val_loss: 0.2340
# Epoch 60/100
# Epoch 00060: val_loss did not improve
#  - 1s - loss: 0.2829 - val_loss: 0.2735
# Epoch 61/100
# Epoch 00061: val_loss did not improve
#  - 1s - loss: 0.2836 - val_loss: 0.2399
# Epoch 62/100
# Epoch 00062: val_loss did not improve
#  - 1s - loss: 0.2801 - val_loss: 0.2448
# Epoch 63/100
# Epoch 00063: val_loss did not improve
#  - 1s - loss: 0.2834 - val_loss: 0.2411
# Epoch 64/100
# Epoch 00064: val_loss improved from 0.23402 to 0.22951, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2797 - val_loss: 0.2295
# Epoch 65/100
# Epoch 00065: val_loss did not improve
#  - 1s - loss: 0.2800 - val_loss: 0.2310
# Epoch 66/100
# Epoch 00066: val_loss did not improve
#  - 1s - loss: 0.2785 - val_loss: 0.2752
# Epoch 67/100
# Epoch 00067: val_loss did not improve
#  - 1s - loss: 0.2792 - val_loss: 0.2604
# Epoch 68/100
# Epoch 00068: val_loss did not improve
#  - 1s - loss: 0.2772 - val_loss: 0.2466
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.2796 - val_loss: 0.2782
# Epoch 70/100
# Epoch 00070: val_loss did not improve
#  - 2s - loss: 0.2773 - val_loss: 0.2370
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.2770 - val_loss: 0.2505
# Epoch 72/100
# Epoch 00072: val_loss did not improve
#  - 1s - loss: 0.2765 - val_loss: 0.2354
# Epoch 73/100
# Epoch 00073: val_loss did not improve
#  - 1s - loss: 0.2751 - val_loss: 0.2335
# Epoch 74/100
# Epoch 00074: val_loss improved from 0.22951 to 0.22858, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2750 - val_loss: 0.2286
# Epoch 75/100
# Epoch 00075: val_loss did not improve
#  - 1s - loss: 0.2736 - val_loss: 0.2472
# Epoch 76/100
# Epoch 00076: val_loss improved from 0.22858 to 0.22381, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2737 - val_loss: 0.2238
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.2747 - val_loss: 0.2385
# Epoch 78/100
# Epoch 00078: val_loss did not improve
#  - 1s - loss: 0.2709 - val_loss: 0.2288
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2721 - val_loss: 0.2348
# Epoch 80/100
# Epoch 00080: val_loss did not improve
#  - 1s - loss: 0.2693 - val_loss: 0.2812
# Epoch 81/100
# Epoch 00081: val_loss did not improve
#  - 1s - loss: 0.2728 - val_loss: 0.2460
# Epoch 82/100
# Epoch 00082: val_loss did not improve
#  - 1s - loss: 0.2697 - val_loss: 0.2418
# Epoch 83/100
# Epoch 00083: val_loss did not improve
#  - 1s - loss: 0.2699 - val_loss: 0.2341
# Epoch 84/100
# Epoch 00084: val_loss improved from 0.22381 to 0.22186, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2666 - val_loss: 0.2219
# Epoch 85/100
# Epoch 00085: val_loss did not improve
#  - 1s - loss: 0.2674 - val_loss: 0.2275
# Epoch 86/100
# Epoch 00086: val_loss did not improve
#  - 1s - loss: 0.2672 - val_loss: 0.2247
# Epoch 87/100
# Epoch 00087: val_loss did not improve
#  - 1s - loss: 0.2703 - val_loss: 0.2347
# Epoch 88/100
# Epoch 00088: val_loss did not improve
#  - 1s - loss: 0.2684 - val_loss: 0.2348
# Epoch 89/100
# Epoch 00089: val_loss did not improve
#  - 1s - loss: 0.2661 - val_loss: 0.2775
# Epoch 90/100
# Epoch 00090: val_loss did not improve
#  - 1s - loss: 0.2661 - val_loss: 0.2301
# Epoch 91/100
# Epoch 00091: val_loss did not improve
#  - 1s - loss: 0.2659 - val_loss: 0.2355
# Epoch 92/100
# Epoch 00092: val_loss did not improve
#  - 1s - loss: 0.2647 - val_loss: 0.2224
# Epoch 93/100
# Epoch 00093: val_loss did not improve
#  - 1s - loss: 0.2643 - val_loss: 0.2237
# Epoch 94/100
# Epoch 00094: val_loss did not improve
#  - 1s - loss: 0.2641 - val_loss: 0.2315
# Epoch 95/100
# Epoch 00095: val_loss improved from 0.22186 to 0.21714, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2643 - val_loss: 0.2171
# Epoch 96/100
# Epoch 00096: val_loss did not improve
#  - 1s - loss: 0.2635 - val_loss: 0.2214
# Epoch 97/100
# Epoch 00097: val_loss did not improve
#  - 1s - loss: 0.2616 - val_loss: 0.2499
# Epoch 98/100
# Epoch 00098: val_loss improved from 0.21714 to 0.21691, saving model to ./hdf5/only_speed_lstm_simple_ChIJ7feGfFdSUkYRmmsyva5Yh7g.best.hdf5
#  - 1s - loss: 0.2633 - val_loss: 0.2169
# Epoch 99/100
# Epoch 00099: val_loss did not improve
#  - 1s - loss: 0.2639 - val_loss: 0.2302
# Epoch 100/100
# Epoch 00100: val_loss did not improve
#  - 1s - loss: 0.2613 - val_loss: 0.2490
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 0.83429, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 2s - loss: 0.9175 - val_loss: 0.8343
# Epoch 2/100
# Epoch 00002: val_loss improved from 0.83429 to 0.72200, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.8117 - val_loss: 0.7220
# Epoch 3/100
# Epoch 00003: val_loss improved from 0.72200 to 0.63093, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.7026 - val_loss: 0.6309
# Epoch 4/100
# Epoch 00004: val_loss improved from 0.63093 to 0.51969, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.5990 - val_loss: 0.5197
# Epoch 5/100
# Epoch 00005: val_loss improved from 0.51969 to 0.46578, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.5199 - val_loss: 0.4658
# Epoch 6/100
# Epoch 00006: val_loss improved from 0.46578 to 0.45528, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4810 - val_loss: 0.4553
# Epoch 7/100
# Epoch 00007: val_loss improved from 0.45528 to 0.42038, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4571 - val_loss: 0.4204
# Epoch 8/100
# Epoch 00008: val_loss improved from 0.42038 to 0.40580, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4398 - val_loss: 0.4058
# Epoch 9/100
# Epoch 00009: val_loss improved from 0.40580 to 0.38937, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4259 - val_loss: 0.3894
# Epoch 10/100
# Epoch 00010: val_loss improved from 0.38937 to 0.37802, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4138 - val_loss: 0.3780
# Epoch 11/100
# Epoch 00011: val_loss improved from 0.37802 to 0.37587, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4087 - val_loss: 0.3759
# Epoch 12/100
# Epoch 00012: val_loss improved from 0.37587 to 0.35909, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.4032 - val_loss: 0.3591
# Epoch 13/100
# Epoch 00013: val_loss did not improve
#  - 1s - loss: 0.3980 - val_loss: 0.3814
# Epoch 14/100
# Epoch 00014: val_loss did not improve
#  - 1s - loss: 0.3937 - val_loss: 0.3785
# Epoch 15/100
# Epoch 00015: val_loss improved from 0.35909 to 0.35391, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3903 - val_loss: 0.3539
# Epoch 16/100
# Epoch 00016: val_loss did not improve
#  - 2s - loss: 0.3836 - val_loss: 0.4138
# Epoch 17/100
# Epoch 00017: val_loss improved from 0.35391 to 0.34843, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3821 - val_loss: 0.3484
# Epoch 18/100
# Epoch 00018: val_loss did not improve
#  - 1s - loss: 0.3812 - val_loss: 0.3542
# Epoch 19/100
# Epoch 00019: val_loss did not improve
#  - 1s - loss: 0.3752 - val_loss: 0.3624
# Epoch 20/100
# Epoch 00020: val_loss improved from 0.34843 to 0.32947, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3750 - val_loss: 0.3295
# Epoch 21/100
# Epoch 00021: val_loss did not improve
#  - 1s - loss: 0.3726 - val_loss: 0.3384
# Epoch 22/100
# Epoch 00022: val_loss did not improve
#  - 1s - loss: 0.3663 - val_loss: 0.3456
# Epoch 23/100
# Epoch 00023: val_loss did not improve
#  - 1s - loss: 0.3709 - val_loss: 0.3637
# Epoch 24/100
# Epoch 00024: val_loss improved from 0.32947 to 0.32865, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3637 - val_loss: 0.3286
# Epoch 25/100
# Epoch 00025: val_loss improved from 0.32865 to 0.32455, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3635 - val_loss: 0.3245
# Epoch 26/100
# Epoch 00026: val_loss improved from 0.32455 to 0.31945, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3626 - val_loss: 0.3194
# Epoch 27/100
# Epoch 00027: val_loss did not improve
#  - 1s - loss: 0.3584 - val_loss: 0.3477
# Epoch 28/100
# Epoch 00028: val_loss improved from 0.31945 to 0.31452, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3548 - val_loss: 0.3145
# Epoch 29/100
# Epoch 00029: val_loss did not improve
#  - 1s - loss: 0.3571 - val_loss: 0.3350
# Epoch 30/100
# Epoch 00030: val_loss did not improve
#  - 1s - loss: 0.3523 - val_loss: 0.3262
# Epoch 31/100
# Epoch 00031: val_loss improved from 0.31452 to 0.30939, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3507 - val_loss: 0.3094
# Epoch 32/100
# Epoch 00032: val_loss improved from 0.30939 to 0.30896, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3518 - val_loss: 0.3090
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 1s - loss: 0.3484 - val_loss: 0.3234
# Epoch 34/100
# Epoch 00034: val_loss did not improve
#  - 1s - loss: 0.3452 - val_loss: 0.3181
# Epoch 35/100
# Epoch 00035: val_loss did not improve
#  - 1s - loss: 0.3446 - val_loss: 0.3110
# Epoch 36/100
# Epoch 00036: val_loss did not improve
#  - 1s - loss: 0.3430 - val_loss: 0.3111
# Epoch 37/100
# Epoch 00037: val_loss did not improve
#  - 1s - loss: 0.3439 - val_loss: 0.3212
# Epoch 38/100
# Epoch 00038: val_loss did not improve
#  - 1s - loss: 0.3405 - val_loss: 0.3282
# Epoch 39/100
# Epoch 00039: val_loss improved from 0.30896 to 0.29901, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3383 - val_loss: 0.2990
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 1s - loss: 0.3379 - val_loss: 0.3323
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 1s - loss: 0.3351 - val_loss: 0.3146
# Epoch 42/100
# Epoch 00042: val_loss did not improve
#  - 1s - loss: 0.3354 - val_loss: 0.3136
# Epoch 43/100
# Epoch 00043: val_loss did not improve
#  - 1s - loss: 0.3335 - val_loss: 0.3218
# Epoch 44/100
# Epoch 00044: val_loss did not improve
#  - 1s - loss: 0.3326 - val_loss: 0.3286
# Epoch 45/100
# Epoch 00045: val_loss did not improve
#  - 1s - loss: 0.3303 - val_loss: 0.3322
# Epoch 46/100
# Epoch 00046: val_loss did not improve
#  - 1s - loss: 0.3283 - val_loss: 0.3192
# Epoch 47/100
# Epoch 00047: val_loss improved from 0.29901 to 0.29441, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3295 - val_loss: 0.2944
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 1s - loss: 0.3286 - val_loss: 0.3159
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 1s - loss: 0.3275 - val_loss: 0.3005
# Epoch 50/100
# Epoch 00050: val_loss did not improve
#  - 1s - loss: 0.3237 - val_loss: 0.2970
# Epoch 51/100
# Epoch 00051: val_loss did not improve
#  - 1s - loss: 0.3253 - val_loss: 0.3013
# Epoch 52/100
# Epoch 00052: val_loss did not improve
#  - 1s - loss: 0.3236 - val_loss: 0.3366
# Epoch 53/100
# Epoch 00053: val_loss improved from 0.29441 to 0.28766, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3181 - val_loss: 0.2877
# Epoch 54/100
# Epoch 00054: val_loss did not improve
#  - 1s - loss: 0.3213 - val_loss: 0.2959
# Epoch 55/100
# Epoch 00055: val_loss improved from 0.28766 to 0.28133, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3198 - val_loss: 0.2813
# Epoch 56/100
# Epoch 00056: val_loss did not improve
#  - 1s - loss: 0.3193 - val_loss: 0.2955
# Epoch 57/100
# Epoch 00057: val_loss improved from 0.28133 to 0.28027, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3175 - val_loss: 0.2803
# Epoch 58/100
# Epoch 00058: val_loss did not improve
#  - 1s - loss: 0.3140 - val_loss: 0.3709
# Epoch 59/100
# Epoch 00059: val_loss improved from 0.28027 to 0.27910, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3159 - val_loss: 0.2791
# Epoch 60/100
# Epoch 00060: val_loss did not improve
#  - 1s - loss: 0.3143 - val_loss: 0.3187
# Epoch 61/100
# Epoch 00061: val_loss did not improve
#  - 1s - loss: 0.3145 - val_loss: 0.2940
# Epoch 62/100
# Epoch 00062: val_loss did not improve
#  - 1s - loss: 0.3104 - val_loss: 0.2959
# Epoch 63/100
# Epoch 00063: val_loss did not improve
#  - 1s - loss: 0.3138 - val_loss: 0.2826
# Epoch 64/100
# Epoch 00064: val_loss did not improve
#  - 1s - loss: 0.3104 - val_loss: 0.2992
# Epoch 65/100
# Epoch 00065: val_loss did not improve
#  - 1s - loss: 0.3088 - val_loss: 0.2904
# Epoch 66/100
# Epoch 00066: val_loss improved from 0.27910 to 0.27620, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3100 - val_loss: 0.2762
# Epoch 67/100
# Epoch 00067: val_loss improved from 0.27620 to 0.27373, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.3064 - val_loss: 0.2737
# Epoch 68/100
# Epoch 00068: val_loss did not improve
#  - 1s - loss: 0.3078 - val_loss: 0.2925
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.3057 - val_loss: 0.2986
# Epoch 70/100
# Epoch 00070: val_loss did not improve
#  - 1s - loss: 0.3060 - val_loss: 0.3199
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.3039 - val_loss: 0.2785
# Epoch 72/100
# Epoch 00072: val_loss did not improve
#  - 1s - loss: 0.3035 - val_loss: 0.2761
# Epoch 73/100
# Epoch 00073: val_loss did not improve
#  - 1s - loss: 0.3017 - val_loss: 0.2841
# Epoch 74/100
# Epoch 00074: val_loss did not improve
#  - 1s - loss: 0.3030 - val_loss: 0.2925
# Epoch 75/100
# Epoch 00075: val_loss did not improve
#  - 1s - loss: 0.3007 - val_loss: 0.2770
# Epoch 76/100
# Epoch 00076: val_loss did not improve
#  - 1s - loss: 0.3028 - val_loss: 0.2745
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.3003 - val_loss: 0.2902
# Epoch 78/100
# Epoch 00078: val_loss improved from 0.27373 to 0.26818, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.2995 - val_loss: 0.2682
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2983 - val_loss: 0.2776
# Epoch 80/100
# Epoch 00080: val_loss improved from 0.26818 to 0.26466, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.2981 - val_loss: 0.2647
# Epoch 81/100
# Epoch 00081: val_loss improved from 0.26466 to 0.26208, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.2968 - val_loss: 0.2621
# Epoch 82/100
# Epoch 00082: val_loss did not improve
#  - 1s - loss: 0.2969 - val_loss: 0.2700
# Epoch 83/100
# Epoch 00083: val_loss did not improve
#  - 1s - loss: 0.2945 - val_loss: 0.2635
# Epoch 84/100
# Epoch 00084: val_loss did not improve
#  - 1s - loss: 0.2945 - val_loss: 0.2663
# Epoch 85/100
# Epoch 00085: val_loss did not improve
#  - 1s - loss: 0.2939 - val_loss: 0.2734
# Epoch 86/100
# Epoch 00086: val_loss did not improve
#  - 1s - loss: 0.2933 - val_loss: 0.2665
# Epoch 87/100
# Epoch 00087: val_loss did not improve
#  - 1s - loss: 0.2932 - val_loss: 0.2785
# Epoch 88/100
# Epoch 00088: val_loss did not improve
#  - 1s - loss: 0.2925 - val_loss: 0.2646
# Epoch 89/100
# Epoch 00089: val_loss did not improve
#  - 1s - loss: 0.2927 - val_loss: 0.2695
# Epoch 90/100
# Epoch 00090: val_loss did not improve
#  - 1s - loss: 0.2906 - val_loss: 0.2957
# Epoch 91/100
# Epoch 00091: val_loss improved from 0.26208 to 0.25735, saving model to ./hdf5/only_speed_lstm_simple_ChIJ3WKEa1dSUkYR4s4cJpaCZfQ.best.hdf5
#  - 1s - loss: 0.2900 - val_loss: 0.2574
# Epoch 92/100
# Epoch 00092: val_loss did not improve
#  - 1s - loss: 0.2919 - val_loss: 0.2716
# Epoch 93/100
# Epoch 00093: val_loss did not improve
#  - 1s - loss: 0.2881 - val_loss: 0.2626
# Epoch 94/100
# Epoch 00094: val_loss did not improve
#  - 1s - loss: 0.2896 - val_loss: 0.2596
# Epoch 95/100
# Epoch 00095: val_loss did not improve
#  - 1s - loss: 0.2880 - val_loss: 0.2609
# Epoch 96/100
# Epoch 00096: val_loss did not improve
#  - 1s - loss: 0.2868 - val_loss: 0.2867
# Epoch 97/100
# Epoch 00097: val_loss did not improve
#  - 1s - loss: 0.2880 - val_loss: 0.2626
# Epoch 98/100
# Epoch 00098: val_loss did not improve
#  - 1s - loss: 0.2860 - val_loss: 0.2580
# Epoch 99/100
# Epoch 00099: val_loss did not improve
#  - 1s - loss: 0.2877 - val_loss: 0.2666
# Epoch 100/100
# Epoch 00100: val_loss did not improve
#  - 1s - loss: 0.2852 - val_loss: 0.2770
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 0.80755, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 2s - loss: 0.9589 - val_loss: 0.8076
# Epoch 2/100
# Epoch 00002: val_loss improved from 0.80755 to 0.68236, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.8442 - val_loss: 0.6824
# Epoch 3/100
# Epoch 00003: val_loss improved from 0.68236 to 0.57434, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.7150 - val_loss: 0.5743
# Epoch 4/100
# Epoch 00004: val_loss improved from 0.57434 to 0.46224, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.5873 - val_loss: 0.4622
# Epoch 5/100
# Epoch 00005: val_loss improved from 0.46224 to 0.42236, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4972 - val_loss: 0.4224
# Epoch 6/100
# Epoch 00006: val_loss improved from 0.42236 to 0.42099, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4663 - val_loss: 0.4210
# Epoch 7/100
# Epoch 00007: val_loss improved from 0.42099 to 0.39343, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4513 - val_loss: 0.3934
# Epoch 8/100
# Epoch 00008: val_loss improved from 0.39343 to 0.38295, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4395 - val_loss: 0.3830
# Epoch 9/100
# Epoch 00009: val_loss improved from 0.38295 to 0.36932, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4294 - val_loss: 0.3693
# Epoch 10/100
# Epoch 00010: val_loss improved from 0.36932 to 0.36538, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4227 - val_loss: 0.3654
# Epoch 11/100
# Epoch 00011: val_loss did not improve
#  - 1s - loss: 0.4153 - val_loss: 0.3759
# Epoch 12/100
# Epoch 00012: val_loss improved from 0.36538 to 0.36474, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4100 - val_loss: 0.3647
# Epoch 13/100
# Epoch 00013: val_loss improved from 0.36474 to 0.35788, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.4066 - val_loss: 0.3579
# Epoch 14/100
# Epoch 00014: val_loss did not improve
#  - 1s - loss: 0.3971 - val_loss: 0.3629
# Epoch 15/100
# Epoch 00015: val_loss did not improve
#  - 1s - loss: 0.3952 - val_loss: 0.3978
# Epoch 16/100
# Epoch 00016: val_loss did not improve
#  - 1s - loss: 0.3898 - val_loss: 0.3716
# Epoch 17/100
# Epoch 00017: val_loss improved from 0.35788 to 0.33275, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3864 - val_loss: 0.3328
# Epoch 18/100
# Epoch 00018: val_loss improved from 0.33275 to 0.32196, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3791 - val_loss: 0.3220
# Epoch 19/100
# Epoch 00019: val_loss improved from 0.32196 to 0.32189, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3740 - val_loss: 0.3219
# Epoch 20/100
# Epoch 00020: val_loss did not improve
#  - 1s - loss: 0.3729 - val_loss: 0.3313
# Epoch 21/100
# Epoch 00021: val_loss improved from 0.32189 to 0.30673, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3672 - val_loss: 0.3067
# Epoch 22/100
# Epoch 00022: val_loss did not improve
#  - 1s - loss: 0.3650 - val_loss: 0.3362
# Epoch 23/100
# Epoch 00023: val_loss did not improve
#  - 1s - loss: 0.3601 - val_loss: 0.3494
# Epoch 24/100
# Epoch 00024: val_loss did not improve
#  - 1s - loss: 0.3623 - val_loss: 0.3774
# Epoch 25/100
# Epoch 00025: val_loss did not improve
#  - 1s - loss: 0.3566 - val_loss: 0.3498
# Epoch 26/100
# Epoch 00026: val_loss did not improve
#  - 1s - loss: 0.3528 - val_loss: 0.3478
# Epoch 27/100
# Epoch 00027: val_loss improved from 0.30673 to 0.28940, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3548 - val_loss: 0.2894
# Epoch 28/100
# Epoch 00028: val_loss did not improve
#  - 1s - loss: 0.3485 - val_loss: 0.3852
# Epoch 29/100
# Epoch 00029: val_loss did not improve
#  - 1s - loss: 0.3492 - val_loss: 0.2917
# Epoch 30/100
# Epoch 00030: val_loss improved from 0.28940 to 0.28395, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3432 - val_loss: 0.2840
# Epoch 31/100
# Epoch 00031: val_loss did not improve
#  - 1s - loss: 0.3465 - val_loss: 0.2992
# Epoch 32/100
# Epoch 00032: val_loss did not improve
#  - 1s - loss: 0.3399 - val_loss: 0.2942
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 1s - loss: 0.3422 - val_loss: 0.3045
# Epoch 34/100
# Epoch 00034: val_loss improved from 0.28395 to 0.28220, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3373 - val_loss: 0.2822
# Epoch 35/100
# Epoch 00035: val_loss improved from 0.28220 to 0.27840, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3372 - val_loss: 0.2784
# Epoch 36/100
# Epoch 00036: val_loss improved from 0.27840 to 0.27692, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3352 - val_loss: 0.2769
# Epoch 37/100
# Epoch 00037: val_loss did not improve
#  - 1s - loss: 0.3352 - val_loss: 0.3126
# Epoch 38/100
# Epoch 00038: val_loss did not improve
#  - 1s - loss: 0.3302 - val_loss: 0.2920
# Epoch 39/100
# Epoch 00039: val_loss did not improve
#  - 1s - loss: 0.3307 - val_loss: 0.2830
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 1s - loss: 0.3292 - val_loss: 0.3054
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 1s - loss: 0.3277 - val_loss: 0.3055
# Epoch 42/100
# Epoch 00042: val_loss did not improve
#  - 1s - loss: 0.3276 - val_loss: 0.3359
# Epoch 43/100
# Epoch 00043: val_loss improved from 0.27692 to 0.27591, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3272 - val_loss: 0.2759
# Epoch 44/100
# Epoch 00044: val_loss improved from 0.27591 to 0.27380, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3238 - val_loss: 0.2738
# Epoch 45/100
# Epoch 00045: val_loss did not improve
#  - 1s - loss: 0.3233 - val_loss: 0.2926
# Epoch 46/100
# Epoch 00046: val_loss improved from 0.27380 to 0.27239, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3223 - val_loss: 0.2724
# Epoch 47/100
# Epoch 00047: val_loss improved from 0.27239 to 0.26951, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3201 - val_loss: 0.2695
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 1s - loss: 0.3194 - val_loss: 0.2966
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 1s - loss: 0.3161 - val_loss: 0.3079
# Epoch 50/100
# Epoch 00050: val_loss did not improve
#  - 1s - loss: 0.3193 - val_loss: 0.2718
# Epoch 51/100
# Epoch 00051: val_loss did not improve
#  - 1s - loss: 0.3141 - val_loss: 0.2777
# Epoch 52/100
# Epoch 00052: val_loss did not improve
#  - 1s - loss: 0.3149 - val_loss: 0.2919
# Epoch 53/100
# Epoch 00053: val_loss did not improve
#  - 1s - loss: 0.3163 - val_loss: 0.2725
# Epoch 54/100
# Epoch 00054: val_loss did not improve
#  - 1s - loss: 0.3147 - val_loss: 0.2929
# Epoch 55/100
# Epoch 00055: val_loss improved from 0.26951 to 0.26069, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3132 - val_loss: 0.2607
# Epoch 56/100
# Epoch 00056: val_loss did not improve
#  - 1s - loss: 0.3105 - val_loss: 0.2919
# Epoch 57/100
# Epoch 00057: val_loss improved from 0.26069 to 0.25666, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3102 - val_loss: 0.2567
# Epoch 58/100
# Epoch 00058: val_loss improved from 0.25666 to 0.25270, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3095 - val_loss: 0.2527
# Epoch 59/100
# Epoch 00059: val_loss did not improve
#  - 1s - loss: 0.3093 - val_loss: 0.2888
# Epoch 60/100
# Epoch 00060: val_loss did not improve
#  - 1s - loss: 0.3066 - val_loss: 0.2601
# Epoch 61/100
# Epoch 00061: val_loss improved from 0.25270 to 0.25090, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3063 - val_loss: 0.2509
# Epoch 62/100
# Epoch 00062: val_loss did not improve
#  - 1s - loss: 0.3057 - val_loss: 0.2697
# Epoch 63/100
# Epoch 00063: val_loss did not improve
#  - 1s - loss: 0.3035 - val_loss: 0.2603
# Epoch 64/100
# Epoch 00064: val_loss did not improve
#  - 1s - loss: 0.3044 - val_loss: 0.2698
# Epoch 65/100
# Epoch 00065: val_loss did not improve
#  - 1s - loss: 0.3014 - val_loss: 0.2735
# Epoch 66/100
# Epoch 00066: val_loss did not improve
#  - 1s - loss: 0.3023 - val_loss: 0.2664
# Epoch 67/100
# Epoch 00067: val_loss did not improve
#  - 1s - loss: 0.3002 - val_loss: 0.2673
# Epoch 68/100
# Epoch 00068: val_loss improved from 0.25090 to 0.25080, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.3007 - val_loss: 0.2508
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.2969 - val_loss: 0.2589
# Epoch 70/100
# Epoch 00070: val_loss did not improve
#  - 1s - loss: 0.2982 - val_loss: 0.2689
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.2974 - val_loss: 0.2770
# Epoch 72/100
# Epoch 00072: val_loss did not improve
#  - 1s - loss: 0.2974 - val_loss: 0.2645
# Epoch 73/100
# Epoch 00073: val_loss improved from 0.25080 to 0.24755, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.2945 - val_loss: 0.2475
# Epoch 74/100
# Epoch 00074: val_loss did not improve
#  - 1s - loss: 0.2944 - val_loss: 0.2814
# Epoch 75/100
# Epoch 00075: val_loss improved from 0.24755 to 0.24549, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.2946 - val_loss: 0.2455
# Epoch 76/100
# Epoch 00076: val_loss improved from 0.24549 to 0.24230, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.2917 - val_loss: 0.2423
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.2922 - val_loss: 0.2466
# Epoch 78/100
# Epoch 00078: val_loss did not improve
#  - 1s - loss: 0.2903 - val_loss: 0.2611
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2911 - val_loss: 0.2457
# Epoch 80/100
# Epoch 00080: val_loss did not improve
#  - 1s - loss: 0.2899 - val_loss: 0.2517
# Epoch 81/100
# Epoch 00081: val_loss improved from 0.24230 to 0.24078, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.2889 - val_loss: 0.2408
# Epoch 82/100
# Epoch 00082: val_loss improved from 0.24078 to 0.23782, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.2880 - val_loss: 0.2378
# Epoch 83/100
# Epoch 00083: val_loss did not improve
#  - 1s - loss: 0.2869 - val_loss: 0.2514
# Epoch 84/100
# Epoch 00084: val_loss did not improve
#  - 1s - loss: 0.2862 - val_loss: 0.2400
# Epoch 85/100
# Epoch 00085: val_loss did not improve
#  - 1s - loss: 0.2844 - val_loss: 0.2886
# Epoch 86/100
# Epoch 00086: val_loss did not improve
#  - 1s - loss: 0.2853 - val_loss: 0.2400
# Epoch 87/100
# Epoch 00087: val_loss did not improve
#  - 1s - loss: 0.2832 - val_loss: 0.2626
# Epoch 88/100
# Epoch 00088: val_loss did not improve
#  - 1s - loss: 0.2823 - val_loss: 0.2409
# Epoch 89/100
# Epoch 00089: val_loss did not improve
#  - 1s - loss: 0.2804 - val_loss: 0.2681
# Epoch 90/100
# Epoch 00090: val_loss did not improve
#  - 1s - loss: 0.2836 - val_loss: 0.2565
# Epoch 91/100
# Epoch 00091: val_loss did not improve
#  - 1s - loss: 0.2799 - val_loss: 0.2586
# Epoch 92/100
# Epoch 00092: val_loss did not improve
#  - 1s - loss: 0.2799 - val_loss: 0.3099
# Epoch 93/100
# Epoch 00093: val_loss did not improve
#  - 1s - loss: 0.2776 - val_loss: 0.2419
# Epoch 94/100
# Epoch 00094: val_loss improved from 0.23782 to 0.23217, saving model to ./hdf5/only_speed_lstm_simple_ChIJCy4tOFhSUkYRBiS5iJUrGnY.best.hdf5
#  - 1s - loss: 0.2789 - val_loss: 0.2322
# Epoch 95/100
# Epoch 00095: val_loss did not improve
#  - 1s - loss: 0.2781 - val_loss: 0.2741
# Epoch 96/100
# Epoch 00096: val_loss did not improve
#  - 1s - loss: 0.2763 - val_loss: 0.2389
# Epoch 97/100
# Epoch 00097: val_loss did not improve
#  - 1s - loss: 0.2750 - val_loss: 0.2755
# Epoch 98/100
# Epoch 00098: val_loss did not improve
#  - 1s - loss: 0.2749 - val_loss: 0.2495
# Epoch 99/100
# Epoch 00099: val_loss did not improve
#  - 1s - loss: 0.2769 - val_loss: 0.2403
# Epoch 100/100
# Epoch 00100: val_loss did not improve
#  - 1s - loss: 0.2740 - val_loss: 0.2599
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 0.79091, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 2s - loss: 0.9480 - val_loss: 0.7909
# Epoch 2/100
# Epoch 00002: val_loss improved from 0.79091 to 0.67690, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.8242 - val_loss: 0.6769
# Epoch 3/100
# Epoch 00003: val_loss improved from 0.67690 to 0.56987, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.7058 - val_loss: 0.5699
# Epoch 4/100
# Epoch 00004: val_loss improved from 0.56987 to 0.48515, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.5895 - val_loss: 0.4852
# Epoch 5/100
# Epoch 00005: val_loss improved from 0.48515 to 0.43368, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.5177 - val_loss: 0.4337
# Epoch 6/100
# Epoch 00006: val_loss improved from 0.43368 to 0.41353, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.4859 - val_loss: 0.4135
# Epoch 7/100
# Epoch 00007: val_loss improved from 0.41353 to 0.39067, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.4646 - val_loss: 0.3907
# Epoch 8/100
# Epoch 00008: val_loss improved from 0.39067 to 0.38919, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.4514 - val_loss: 0.3892
# Epoch 9/100
# Epoch 00009: val_loss did not improve
#  - 1s - loss: 0.4418 - val_loss: 0.3938
# Epoch 10/100
# Epoch 00010: val_loss did not improve
#  - 1s - loss: 0.4325 - val_loss: 0.3952
# Epoch 11/100
# Epoch 00011: val_loss improved from 0.38919 to 0.36712, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.4247 - val_loss: 0.3671
# Epoch 12/100
# Epoch 00012: val_loss improved from 0.36712 to 0.35457, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.4202 - val_loss: 0.3546
# Epoch 13/100
# Epoch 00013: val_loss did not improve
#  - 1s - loss: 0.4132 - val_loss: 0.3686
# Epoch 14/100
# Epoch 00014: val_loss improved from 0.35457 to 0.33343, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.4052 - val_loss: 0.3334
# Epoch 15/100
# Epoch 00015: val_loss did not improve
#  - 1s - loss: 0.4019 - val_loss: 0.3489
# Epoch 16/100
# Epoch 00016: val_loss did not improve
#  - 1s - loss: 0.3983 - val_loss: 0.3400
# Epoch 17/100
# Epoch 00017: val_loss did not improve
#  - 1s - loss: 0.3934 - val_loss: 0.3823
# Epoch 18/100
# Epoch 00018: val_loss did not improve
#  - 1s - loss: 0.3877 - val_loss: 0.3466
# Epoch 19/100
# Epoch 00019: val_loss improved from 0.33343 to 0.32052, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3825 - val_loss: 0.3205
# Epoch 20/100
# Epoch 00020: val_loss improved from 0.32052 to 0.30978, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3838 - val_loss: 0.3098
# Epoch 21/100
# Epoch 00021: val_loss did not improve
#  - 1s - loss: 0.3781 - val_loss: 0.3305
# Epoch 22/100
# Epoch 00022: val_loss did not improve
#  - 1s - loss: 0.3734 - val_loss: 0.3182
# Epoch 23/100
# Epoch 00023: val_loss did not improve
#  - 1s - loss: 0.3711 - val_loss: 0.3322
# Epoch 24/100
# Epoch 00024: val_loss did not improve
#  - 2s - loss: 0.3677 - val_loss: 0.3240
# Epoch 25/100
# Epoch 00025: val_loss improved from 0.30978 to 0.30808, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3651 - val_loss: 0.3081
# Epoch 26/100
# Epoch 00026: val_loss improved from 0.30808 to 0.30563, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3607 - val_loss: 0.3056
# Epoch 27/100
# Epoch 00027: val_loss improved from 0.30563 to 0.29549, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3583 - val_loss: 0.2955
# Epoch 28/100
# Epoch 00028: val_loss did not improve
#  - 1s - loss: 0.3562 - val_loss: 0.3507
# Epoch 29/100
# Epoch 00029: val_loss did not improve
#  - 1s - loss: 0.3516 - val_loss: 0.3052
# Epoch 30/100
# Epoch 00030: val_loss did not improve
#  - 1s - loss: 0.3489 - val_loss: 0.3010
# Epoch 31/100
# Epoch 00031: val_loss improved from 0.29549 to 0.29393, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3468 - val_loss: 0.2939
# Epoch 32/100
# Epoch 00032: val_loss did not improve
#  - 1s - loss: 0.3425 - val_loss: 0.3697
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 1s - loss: 0.3425 - val_loss: 0.2979
# Epoch 34/100
# Epoch 00034: val_loss improved from 0.29393 to 0.27585, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3394 - val_loss: 0.2758
# Epoch 35/100
# Epoch 00035: val_loss improved from 0.27585 to 0.27520, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3333 - val_loss: 0.2752
# Epoch 36/100
# Epoch 00036: val_loss did not improve
#  - 1s - loss: 0.3316 - val_loss: 0.3055
# Epoch 37/100
# Epoch 00037: val_loss did not improve
#  - 1s - loss: 0.3295 - val_loss: 0.2847
# Epoch 38/100
# Epoch 00038: val_loss did not improve
#  - 1s - loss: 0.3301 - val_loss: 0.2806
# Epoch 39/100
# Epoch 00039: val_loss did not improve
#  - 1s - loss: 0.3232 - val_loss: 0.2852
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 1s - loss: 0.3256 - val_loss: 0.2968
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 1s - loss: 0.3192 - val_loss: 0.2753
# Epoch 42/100
# Epoch 00042: val_loss improved from 0.27520 to 0.26097, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3174 - val_loss: 0.2610
# Epoch 43/100
# Epoch 00043: val_loss did not improve
#  - 1s - loss: 0.3147 - val_loss: 0.2748
# Epoch 44/100
# Epoch 00044: val_loss did not improve
#  - 1s - loss: 0.3142 - val_loss: 0.2829
# Epoch 45/100
# Epoch 00045: val_loss improved from 0.26097 to 0.25628, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.3116 - val_loss: 0.2563
# Epoch 46/100
# Epoch 00046: val_loss did not improve
#  - 1s - loss: 0.3091 - val_loss: 0.2564
# Epoch 47/100
# Epoch 00047: val_loss did not improve
#  - 1s - loss: 0.3085 - val_loss: 0.2750
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 1s - loss: 0.3063 - val_loss: 0.2772
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 1s - loss: 0.3028 - val_loss: 0.2591
# Epoch 50/100
# Epoch 00050: val_loss did not improve
#  - 1s - loss: 0.3032 - val_loss: 0.2605
# Epoch 51/100
# Epoch 00051: val_loss improved from 0.25628 to 0.25143, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.2999 - val_loss: 0.2514
# Epoch 52/100
# Epoch 00052: val_loss did not improve
#  - 1s - loss: 0.3009 - val_loss: 0.2690
# Epoch 53/100
# Epoch 00053: val_loss did not improve
#  - 1s - loss: 0.2969 - val_loss: 0.2654
# Epoch 54/100
# Epoch 00054: val_loss did not improve
#  - 1s - loss: 0.2971 - val_loss: 0.2644
# Epoch 55/100
# Epoch 00055: val_loss did not improve
#  - 1s - loss: 0.2950 - val_loss: 0.2802
# Epoch 56/100
# Epoch 00056: val_loss improved from 0.25143 to 0.24343, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.2942 - val_loss: 0.2434
# Epoch 57/100
# Epoch 00057: val_loss did not improve
#  - 1s - loss: 0.2918 - val_loss: 0.2448
# Epoch 58/100
# Epoch 00058: val_loss did not improve
#  - 1s - loss: 0.2911 - val_loss: 0.2459
# Epoch 59/100
# Epoch 00059: val_loss improved from 0.24343 to 0.23914, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.2896 - val_loss: 0.2391
# Epoch 60/100
# Epoch 00060: val_loss did not improve
#  - 1s - loss: 0.2904 - val_loss: 0.2396
# Epoch 61/100
# Epoch 00061: val_loss did not improve
#  - 1s - loss: 0.2898 - val_loss: 0.2502
# Epoch 62/100
# Epoch 00062: val_loss did not improve
#  - 1s - loss: 0.2867 - val_loss: 0.2549
# Epoch 63/100
# Epoch 00063: val_loss did not improve
#  - 1s - loss: 0.2856 - val_loss: 0.2425
# Epoch 64/100
# Epoch 00064: val_loss did not improve
#  - 1s - loss: 0.2834 - val_loss: 0.2462
# Epoch 65/100
# Epoch 00065: val_loss did not improve
#  - 1s - loss: 0.2839 - val_loss: 0.2550
# Epoch 66/100
# Epoch 00066: val_loss did not improve
#  - 1s - loss: 0.2844 - val_loss: 0.2634
# Epoch 67/100
# Epoch 00067: val_loss did not improve
#  - 1s - loss: 0.2805 - val_loss: 0.2772
# Epoch 68/100
# Epoch 00068: val_loss did not improve
#  - 1s - loss: 0.2820 - val_loss: 0.2451
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.2822 - val_loss: 0.2543
# Epoch 70/100
# Epoch 00070: val_loss did not improve
#  - 1s - loss: 0.2799 - val_loss: 0.2489
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.2786 - val_loss: 0.2510
# Epoch 72/100
# Epoch 00072: val_loss improved from 0.23914 to 0.23245, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.2785 - val_loss: 0.2325
# Epoch 73/100
# Epoch 00073: val_loss did not improve
#  - 1s - loss: 0.2784 - val_loss: 0.2549
# Epoch 74/100
# Epoch 00074: val_loss did not improve
#  - 1s - loss: 0.2752 - val_loss: 0.2341
# Epoch 75/100
# Epoch 00075: val_loss did not improve
#  - 1s - loss: 0.2770 - val_loss: 0.2691
# Epoch 76/100
# Epoch 00076: val_loss did not improve
#  - 1s - loss: 0.2734 - val_loss: 0.2639
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.2759 - val_loss: 0.2486
# Epoch 78/100
# Epoch 00078: val_loss improved from 0.23245 to 0.23013, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.2731 - val_loss: 0.2301
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2737 - val_loss: 0.2599
# Epoch 80/100
# Epoch 00080: val_loss improved from 0.23013 to 0.22946, saving model to ./hdf5/only_speed_lstm_simple_ChIJjz-_3_BSUkYRRk9hBB16k-Q.best.hdf5
#  - 1s - loss: 0.2727 - val_loss: 0.2295
# Epoch 81/100
# Epoch 00081: val_loss did not improve
#  - 1s - loss: 0.2701 - val_loss: 0.2512
# Epoch 82/100
# Epoch 00082: val_loss did not improve
#  - 1s - loss: 0.2717 - val_loss: 0.2344
# Epoch 83/100
# ...
# Epoch 64/100
# Epoch 00064: val_loss did not improve
#  - 1s - loss: 0.2815 - val_loss: 0.2635
# Epoch 65/100
# Epoch 00065: val_loss did not improve
#  - 1s - loss: 0.2800 - val_loss: 0.2433
# Epoch 66/100
# Epoch 00066: val_loss improved from 0.24297 to 0.23187, saving model to ./hdf5/only_speed_lstm_simple_ChIJsde_glVSUkYRlK8i5BD3BOA.best.hdf5
#  - 1s - loss: 0.2771 - val_loss: 0.2319
# Epoch 67/100
# Epoch 00067: val_loss did not improve
#  - 1s - loss: 0.2779 - val_loss: 0.2583
# Epoch 68/100
# Epoch 00068: val_loss improved from 0.23187 to 0.23163, saving model to ./hdf5/only_speed_lstm_simple_ChIJsde_glVSUkYRlK8i5BD3BOA.best.hdf5
#  - 1s - loss: 0.2748 - val_loss: 0.2316
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.2755 - val_loss: 0.2362
# Epoch 70/100
# Epoch 00070: val_loss did not improve
#  - 1s - loss: 0.2755 - val_loss: 0.2876
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.2726 - val_loss: 0.2523
# Epoch 72/100
# Epoch 00072: val_loss did not improve
#  - 1s - loss: 0.2725 - val_loss: 0.2727
# Epoch 73/100
# Epoch 00073: val_loss did not improve
#  - 1s - loss: 0.2702 - val_loss: 0.2429
# Epoch 74/100
# Epoch 00074: val_loss did not improve
#  - 1s - loss: 0.2717 - val_loss: 0.2469
# Epoch 75/100
# Epoch 00075: val_loss did not improve
#  - 1s - loss: 0.2692 - val_loss: 0.2522
# Epoch 76/100
# Epoch 00076: val_loss did not improve
#  - 1s - loss: 0.2683 - val_loss: 0.2450
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.2676 - val_loss: 0.2583
# Epoch 78/100
# Epoch 00078: val_loss improved from 0.23163 to 0.22930, saving model to ./hdf5/only_speed_lstm_simple_ChIJsde_glVSUkYRlK8i5BD3BOA.best.hdf5
#  - 1s - loss: 0.2668 - val_loss: 0.2293
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2670 - val_loss: 0.2558
# Epoch 80/100
# Epoch 00080: val_loss improved from 0.22930 to 0.22187, saving model to ./hdf5/only_speed_lstm_simple_ChIJsde_glVSUkYRlK8i5BD3BOA.best.hdf5
#  - 1s - loss: 0.2663 - val_loss: 0.2219
# Epoch 81/100
# Epoch 00081: val_loss did not improve
#  - 1s - loss: 0.2651 - val_loss: 0.2226
# Epoch 82/100
# Epoch 00082: val_loss improved from 0.22187 to 0.22015, saving model to ./hdf5/only_speed_lstm_simple_ChIJsde_glVSUkYRlK8i5BD3BOA.best.hdf5
#  - 1s - loss: 0.2625 - val_loss: 0.2202
# Epoch 83/100
# Epoch 00083: val_loss did not improve
#  - 1s - loss: 0.2635 - val_loss: 0.2254
# Epoch 84/100
# Epoch 00084: val_loss did not improve
#  - 1s - loss: 0.2605 - val_loss: 0.2578
# Epoch 85/100
# Epoch 00085: val_loss did not improve
#  - 1s - loss: 0.2588 - val_loss: 0.2515
# Epoch 86/100
# Epoch 00086: val_loss did not improve
#  - 1s - loss: 0.2588 - val_loss: 0.2399
# Epoch 87/100
# Epoch 00087: val_loss did not improve
#  - 1s - loss: 0.2585 - val_loss: 0.2308
# Epoch 88/100
# Epoch 00088: val_loss did not improve
#  - 1s - loss: 0.2562 - val_loss: 0.2402
# Epoch 89/100
# Epoch 00089: val_loss did not improve
#  - 1s - loss: 0.2566 - val_loss: 0.2293
# Epoch 90/100
# Epoch 00090: val_loss improved from 0.22015 to 0.21317, saving model to ./hdf5/only_speed_lstm_simple_ChIJsde_glVSUkYRlK8i5BD3BOA.best.hdf5
#  - 1s - loss: 0.2570 - val_loss: 0.2132
# Epoch 91/100
# Epoch 00091: val_loss did not improve
#  - 1s - loss: 0.2537 - val_loss: 0.2335
# Epoch 92/100
# Epoch 00092: val_loss did not improve
#  - 1s - loss: 0.2557 - val_loss: 0.2400
# Epoch 93/100
# Epoch 00093: val_loss did not improve
#  - 1s - loss: 0.2531 - val_loss: 0.2489
# Epoch 94/100
# Epoch 00094: val_loss did not improve
#  - 1s - loss: 0.2536 - val_loss: 0.2200
# Epoch 95/100
# Epoch 00095: val_loss did not improve
#  - 1s - loss: 0.2508 - val_loss: 0.2317
# Epoch 96/100
# Epoch 00096: val_loss did not improve
#  - 1s - loss: 0.2507 - val_loss: 0.2186
# Epoch 97/100
# Epoch 00097: val_loss did not improve
#  - 1s - loss: 0.2491 - val_loss: 0.2311
# Epoch 98/100
# Epoch 00098: val_loss did not improve
#  - 1s - loss: 0.2507 - val_loss: 0.2270
# Epoch 99/100
# Epoch 00099: val_loss did not improve
#  - 1s - loss: 0.2479 - val_loss: 0.2208
# Epoch 100/100
# Epoch 00100: val_loss did not improve
#  - 1s - loss: 0.2477 - val_loss: 0.2151
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 0.73846, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 3s - loss: 0.9275 - val_loss: 0.7385
# Epoch 2/100
# Epoch 00002: val_loss improved from 0.73846 to 0.63721, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.8022 - val_loss: 0.6372
# Epoch 3/100
# Epoch 00003: val_loss improved from 0.63721 to 0.54142, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.6886 - val_loss: 0.5414
# Epoch 4/100
# Epoch 00004: val_loss improved from 0.54142 to 0.45938, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.5614 - val_loss: 0.4594
# Epoch 5/100
# Epoch 00005: val_loss improved from 0.45938 to 0.40328, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.4798 - val_loss: 0.4033
# Epoch 6/100
# Epoch 00006: val_loss improved from 0.40328 to 0.38503, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.4498 - val_loss: 0.3850
# Epoch 7/100
# Epoch 00007: val_loss improved from 0.38503 to 0.37074, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.4342 - val_loss: 0.3707
# Epoch 8/100
# Epoch 00008: val_loss did not improve
#  - 1s - loss: 0.4212 - val_loss: 0.3861
# Epoch 9/100
# Epoch 00009: val_loss did not improve
#  - 1s - loss: 0.4147 - val_loss: 0.3955
# Epoch 10/100
# Epoch 00010: val_loss improved from 0.37074 to 0.35754, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 2s - loss: 0.4079 - val_loss: 0.3575
# Epoch 11/100
# Epoch 00011: val_loss improved from 0.35754 to 0.35087, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3987 - val_loss: 0.3509
# Epoch 12/100
# Epoch 00012: val_loss improved from 0.35087 to 0.32858, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 2s - loss: 0.3930 - val_loss: 0.3286
# Epoch 13/100
# Epoch 00013: val_loss improved from 0.32858 to 0.32856, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 2s - loss: 0.3896 - val_loss: 0.3286
# Epoch 14/100
# Epoch 00014: val_loss did not improve
#  - 2s - loss: 0.3829 - val_loss: 0.3893
# Epoch 15/100
# Epoch 00015: val_loss did not improve
#  - 1s - loss: 0.3771 - val_loss: 0.3389
# Epoch 16/100
# Epoch 00016: val_loss did not improve
#  - 1s - loss: 0.3755 - val_loss: 0.3467
# Epoch 17/100
# Epoch 00017: val_loss improved from 0.32856 to 0.31775, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3714 - val_loss: 0.3178
# Epoch 18/100
# Epoch 00018: val_loss improved from 0.31775 to 0.30563, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3678 - val_loss: 0.3056
# Epoch 19/100
# Epoch 00019: val_loss improved from 0.30563 to 0.30530, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3626 - val_loss: 0.3053
# Epoch 20/100
# Epoch 00020: val_loss did not improve
#  - 1s - loss: 0.3608 - val_loss: 0.3394
# Epoch 21/100
# Epoch 00021: val_loss did not improve
#  - 1s - loss: 0.3566 - val_loss: 0.3321
# Epoch 22/100
# Epoch 00022: val_loss did not improve
#  - 2s - loss: 0.3561 - val_loss: 0.3594
# Epoch 23/100
# Epoch 00023: val_loss did not improve
#  - 2s - loss: 0.3512 - val_loss: 0.3152
# Epoch 24/100
# Epoch 00024: val_loss improved from 0.30530 to 0.30035, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 2s - loss: 0.3493 - val_loss: 0.3004
# Epoch 25/100
# Epoch 00025: val_loss improved from 0.30035 to 0.28853, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3503 - val_loss: 0.2885
# Epoch 26/100
# Epoch 00026: val_loss did not improve
#  - 2s - loss: 0.3461 - val_loss: 0.2896
# Epoch 27/100
# Epoch 00027: val_loss did not improve
#  - 1s - loss: 0.3444 - val_loss: 0.3140
# Epoch 28/100
# Epoch 00028: val_loss did not improve
#  - 1s - loss: 0.3406 - val_loss: 0.3066
# Epoch 29/100
# Epoch 00029: val_loss improved from 0.28853 to 0.28512, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3378 - val_loss: 0.2851
# Epoch 30/100
# Epoch 00030: val_loss did not improve
#  - 1s - loss: 0.3400 - val_loss: 0.3314
# Epoch 31/100
# Epoch 00031: val_loss did not improve
#  - 1s - loss: 0.3362 - val_loss: 0.3009
# Epoch 32/100
# Epoch 00032: val_loss did not improve
#  - 1s - loss: 0.3330 - val_loss: 0.2856
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 1s - loss: 0.3304 - val_loss: 0.3587
# Epoch 34/100
# Epoch 00034: val_loss did not improve
#  - 1s - loss: 0.3313 - val_loss: 0.3171
# Epoch 35/100
# Epoch 00035: val_loss improved from 0.28512 to 0.28294, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3295 - val_loss: 0.2829
# Epoch 36/100
# Epoch 00036: val_loss did not improve
#  - 1s - loss: 0.3278 - val_loss: 0.3194
# Epoch 37/100
# Epoch 00037: val_loss did not improve
#  - 1s - loss: 0.3243 - val_loss: 0.2902
# Epoch 38/100
# Epoch 00038: val_loss improved from 0.28294 to 0.26521, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3237 - val_loss: 0.2652
# Epoch 39/100
# Epoch 00039: val_loss did not improve
#  - 1s - loss: 0.3250 - val_loss: 0.2735
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 1s - loss: 0.3203 - val_loss: 0.2725
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 1s - loss: 0.3197 - val_loss: 0.2799
# Epoch 42/100
# Epoch 00042: val_loss did not improve
#  - 1s - loss: 0.3186 - val_loss: 0.2925
# Epoch 43/100
# Epoch 00043: val_loss did not improve
#  - 1s - loss: 0.3185 - val_loss: 0.2984
# Epoch 44/100
# Epoch 00044: val_loss did not improve
#  - 1s - loss: 0.3144 - val_loss: 0.2795
# Epoch 45/100
# Epoch 00045: val_loss improved from 0.26521 to 0.25679, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3149 - val_loss: 0.2568
# Epoch 46/100
# Epoch 00046: val_loss did not improve
#  - 1s - loss: 0.3108 - val_loss: 0.2865
# Epoch 47/100
# Epoch 00047: val_loss did not improve
#  - 1s - loss: 0.3141 - val_loss: 0.2989
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 1s - loss: 0.3092 - val_loss: 0.2722
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 1s - loss: 0.3101 - val_loss: 0.2772
# Epoch 50/100
# Epoch 00050: val_loss did not improve
#  - 1s - loss: 0.3084 - val_loss: 0.2717
# Epoch 51/100
# Epoch 00051: val_loss did not improve
#  - 1s - loss: 0.3079 - val_loss: 0.2758
# Epoch 52/100
# Epoch 00052: val_loss did not improve
#  - 1s - loss: 0.3043 - val_loss: 0.2666
# Epoch 53/100
# Epoch 00053: val_loss improved from 0.25679 to 0.25606, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3033 - val_loss: 0.2561
# Epoch 54/100
# Epoch 00054: val_loss did not improve
#  - 1s - loss: 0.3018 - val_loss: 0.2880
# Epoch 55/100
# Epoch 00055: val_loss did not improve
#  - 1s - loss: 0.3027 - val_loss: 0.2859
# Epoch 56/100
# Epoch 00056: val_loss improved from 0.25606 to 0.24626, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.3013 - val_loss: 0.2463
# Epoch 57/100
# Epoch 00057: val_loss did not improve
#  - 1s - loss: 0.3018 - val_loss: 0.3184
# Epoch 58/100
# Epoch 00058: val_loss did not improve
#  - 1s - loss: 0.2977 - val_loss: 0.3108
# Epoch 59/100
# Epoch 00059: val_loss did not improve
#  - 1s - loss: 0.2978 - val_loss: 0.2734
# Epoch 60/100
# Epoch 00060: val_loss did not improve
#  - 1s - loss: 0.2986 - val_loss: 0.2610
# Epoch 61/100
# Epoch 00061: val_loss did not improve
#  - 1s - loss: 0.2964 - val_loss: 0.2505
# Epoch 62/100
# Epoch 00062: val_loss did not improve
#  - 1s - loss: 0.2942 - val_loss: 0.2671
# Epoch 63/100
# Epoch 00063: val_loss did not improve
#  - 1s - loss: 0.2933 - val_loss: 0.2560
# Epoch 64/100
# Epoch 00064: val_loss improved from 0.24626 to 0.24306, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.2910 - val_loss: 0.2431
# Epoch 65/100
# Epoch 00065: val_loss did not improve
#  - 1s - loss: 0.2915 - val_loss: 0.2752
# Epoch 66/100
# Epoch 00066: val_loss did not improve
#  - 1s - loss: 0.2884 - val_loss: 0.2441
# Epoch 67/100
# Epoch 00067: val_loss did not improve
#  - 1s - loss: 0.2907 - val_loss: 0.2864
# Epoch 68/100
# Epoch 00068: val_loss improved from 0.24306 to 0.23440, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.2872 - val_loss: 0.2344
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.2855 - val_loss: 0.2616
# Epoch 70/100
# Epoch 00070: val_loss improved from 0.23440 to 0.23309, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.2850 - val_loss: 0.2331
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.2836 - val_loss: 0.2443
# Epoch 72/100
# Epoch 00072: val_loss did not improve
#  - 1s - loss: 0.2831 - val_loss: 0.2765
# Epoch 73/100
# Epoch 00073: val_loss did not improve
#  - 1s - loss: 0.2817 - val_loss: 0.2718
# Epoch 74/100
# Epoch 00074: val_loss did not improve
#  - 1s - loss: 0.2815 - val_loss: 0.2603
# Epoch 75/100
# Epoch 00075: val_loss did not improve
#  - 1s - loss: 0.2805 - val_loss: 0.2464
# Epoch 76/100
# Epoch 00076: val_loss did not improve
#  - 1s - loss: 0.2785 - val_loss: 0.2856
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.2759 - val_loss: 0.2591
# Epoch 78/100
# Epoch 00078: val_loss improved from 0.23309 to 0.22911, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.2772 - val_loss: 0.2291
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2755 - val_loss: 0.2440
# Epoch 80/100
# Epoch 00080: val_loss did not improve
#  - 1s - loss: 0.2767 - val_loss: 0.2293
# Epoch 81/100
# Epoch 00081: val_loss did not improve
#  - 1s - loss: 0.2710 - val_loss: 0.2384
# Epoch 82/100
# Epoch 00082: val_loss did not improve
#  - 1s - loss: 0.2754 - val_loss: 0.2335
# Epoch 83/100
# Epoch 00083: val_loss did not improve
#  - 1s - loss: 0.2691 - val_loss: 0.2810
# Epoch 84/100
# Epoch 00084: val_loss did not improve
#  - 1s - loss: 0.2715 - val_loss: 0.2493
# Epoch 85/100
# Epoch 00085: val_loss did not improve
#  - 1s - loss: 0.2724 - val_loss: 0.2380
# Epoch 86/100
# Epoch 00086: val_loss did not improve
#  - 1s - loss: 0.2693 - val_loss: 0.2749
# Epoch 87/100
# Epoch 00087: val_loss did not improve
#  - 1s - loss: 0.2674 - val_loss: 0.2430
# Epoch 88/100
# Epoch 00088: val_loss did not improve
#  - 1s - loss: 0.2671 - val_loss: 0.2426
# Epoch 89/100
# Epoch 00089: val_loss did not improve
#  - 1s - loss: 0.2648 - val_loss: 0.2310
# Epoch 90/100
# Epoch 00090: val_loss improved from 0.22911 to 0.22034, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.2647 - val_loss: 0.2203
# Epoch 91/100
# Epoch 00091: val_loss did not improve
#  - 1s - loss: 0.2634 - val_loss: 0.2344
# Epoch 92/100
# Epoch 00092: val_loss did not improve
#  - 1s - loss: 0.2623 - val_loss: 0.3030
# Epoch 93/100
# Epoch 00093: val_loss improved from 0.22034 to 0.21792, saving model to ./hdf5/only_speed_lstm_simple_ChIJozaGTFZSUkYRjY7TpiWcsro.best.hdf5
#  - 1s - loss: 0.2634 - val_loss: 0.2179
# Epoch 94/100
# Epoch 00094: val_loss did not improve
#  - 1s - loss: 0.2639 - val_loss: 0.2464
# Epoch 95/100
# Epoch 00095: val_loss did not improve
#  - 1s - loss: 0.2615 - val_loss: 0.2479
# Epoch 96/100
# Epoch 00096: val_loss did not improve
#  - 1s - loss: 0.2596 - val_loss: 0.2314
# Epoch 97/100
# Epoch 00097: val_loss did not improve
#  - 1s - loss: 0.2593 - val_loss: 0.2293
# Epoch 98/100
# Epoch 00098: val_loss did not improve
#  - 1s - loss: 0.2579 - val_loss: 0.2179
# Epoch 99/100
# Epoch 00099: val_loss did not improve
#  - 1s - loss: 0.2590 - val_loss: 0.2519
# Epoch 100/100
# Epoch 00100: val_loss did not improve
#  - 1s - loss: 0.2571 - val_loss: 0.2315

# %%
multiple_places(place_groups_junctions, 'place_groups_junctions')
# Out:
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00001: val_loss improved from inf to 0.74184, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 3s - loss: 0.9266 - val_loss: 0.7418
# Epoch 2/100
# Epoch 00002: val_loss improved from 0.74184 to 0.62929, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.8016 - val_loss: 0.6293
# Epoch 3/100
# Epoch 00003: val_loss improved from 0.62929 to 0.51400, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.6804 - val_loss: 0.5140
# Epoch 4/100
# Epoch 00004: val_loss improved from 0.51400 to 0.45492, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.5620 - val_loss: 0.4549
# Epoch 5/100
# Epoch 00005: val_loss improved from 0.45492 to 0.40627, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.5024 - val_loss: 0.4063
# Epoch 6/100
# Epoch 00006: val_loss did not improve
#  - 1s - loss: 0.4736 - val_loss: 0.4477
# Epoch 7/100
# Epoch 00007: val_loss improved from 0.40627 to 0.36581, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.4579 - val_loss: 0.3658
# Epoch 8/100
# Epoch 00008: val_loss improved from 0.36581 to 0.35787, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.4430 - val_loss: 0.3579
# Epoch 9/100
# Epoch 00009: val_loss improved from 0.35787 to 0.35729, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.4340 - val_loss: 0.3573
# Epoch 10/100
# Epoch 00010: val_loss improved from 0.35729 to 0.34421, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.4241 - val_loss: 0.3442
# Epoch 11/100
# Epoch 00011: val_loss did not improve
#  - 1s - loss: 0.4180 - val_loss: 0.3512
# Epoch 12/100
# Epoch 00012: val_loss improved from 0.34421 to 0.32101, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.4102 - val_loss: 0.3210
# Epoch 13/100
# Epoch 00013: val_loss did not improve
#  - 1s - loss: 0.4028 - val_loss: 0.3611
# Epoch 14/100
# Epoch 00014: val_loss improved from 0.32101 to 0.30271, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3940 - val_loss: 0.3027
# Epoch 15/100
# Epoch 00015: val_loss did not improve
#  - 1s - loss: 0.3897 - val_loss: 0.3040
# Epoch 16/100
# Epoch 00016: val_loss improved from 0.30271 to 0.30101, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3810 - val_loss: 0.3010
# Epoch 17/100
# Epoch 00017: val_loss did not improve
#  - 1s - loss: 0.3753 - val_loss: 0.3084
# Epoch 18/100
# Epoch 00018: val_loss improved from 0.30101 to 0.28313, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3754 - val_loss: 0.2831
# Epoch 19/100
# Epoch 00019: val_loss did not improve
#  - 1s - loss: 0.3677 - val_loss: 0.2852
# Epoch 20/100
# Epoch 00020: val_loss did not improve
#  - 1s - loss: 0.3623 - val_loss: 0.2938
# Epoch 21/100
# Epoch 00021: val_loss improved from 0.28313 to 0.28053, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3607 - val_loss: 0.2805
# Epoch 22/100
# Epoch 00022: val_loss improved from 0.28053 to 0.27923, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3593 - val_loss: 0.2792
# Epoch 23/100
# Epoch 00023: val_loss improved from 0.27923 to 0.27334, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3546 - val_loss: 0.2733
# Epoch 24/100
# Epoch 00024: val_loss did not improve
#  - 1s - loss: 0.3505 - val_loss: 0.3820
# Epoch 25/100
# Epoch 00025: val_loss did not improve
#  - 1s - loss: 0.3502 - val_loss: 0.2832
# Epoch 26/100
# Epoch 00026: val_loss improved from 0.27334 to 0.25984, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3441 - val_loss: 0.2598
# Epoch 27/100
# Epoch 00027: val_loss did not improve
#  - 1s - loss: 0.3436 - val_loss: 0.2747
# Epoch 28/100
# Epoch 00028: val_loss improved from 0.25984 to 0.25888, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3427 - val_loss: 0.2589
# Epoch 29/100
# Epoch 00029: val_loss did not improve
#  - 1s - loss: 0.3360 - val_loss: 0.3162
# Epoch 30/100
# Epoch 00030: val_loss did not improve
#  - 1s - loss: 0.3363 - val_loss: 0.2926
# Epoch 31/100
# Epoch 00031: val_loss did not improve
#  - 1s - loss: 0.3346 - val_loss: 0.2902
# Epoch 32/100
# Epoch 00032: val_loss improved from 0.25888 to 0.25191, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3353 - val_loss: 0.2519
# Epoch 33/100
# Epoch 00033: val_loss did not improve
#  - 1s - loss: 0.3295 - val_loss: 0.2590
# Epoch 34/100
# Epoch 00034: val_loss did not improve
#  - 1s - loss: 0.3293 - val_loss: 0.2722
# Epoch 35/100
# Epoch 00035: val_loss did not improve
#  - 1s - loss: 0.3271 - val_loss: 0.2640
# Epoch 36/100
# Epoch 00036: val_loss did not improve
#  - 1s - loss: 0.3236 - val_loss: 0.2734
# Epoch 37/100
# Epoch 00037: val_loss improved from 0.25191 to 0.24609, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3221 - val_loss: 0.2461
# Epoch 38/100
# Epoch 00038: val_loss did not improve
#  - 1s - loss: 0.3194 - val_loss: 0.2538
# Epoch 39/100
# Epoch 00039: val_loss did not improve
#  - 1s - loss: 0.3175 - val_loss: 0.2465
# Epoch 40/100
# Epoch 00040: val_loss did not improve
#  - 1s - loss: 0.3200 - val_loss: 0.2612
# Epoch 41/100
# Epoch 00041: val_loss did not improve
#  - 1s - loss: 0.3154 - val_loss: 0.2710
# Epoch 42/100
# Epoch 00042: val_loss did not improve
#  - 1s - loss: 0.3141 - val_loss: 0.2520
# Epoch 43/100
# Epoch 00043: val_loss did not improve
#  - 1s - loss: 0.3110 - val_loss: 0.2506
# Epoch 44/100
# Epoch 00044: val_loss did not improve
#  - 1s - loss: 0.3099 - val_loss: 0.2560
# Epoch 45/100
# Epoch 00045: val_loss did not improve
#  - 1s - loss: 0.3088 - val_loss: 0.2489
# Epoch 46/100
# Epoch 00046: val_loss improved from 0.24609 to 0.23667, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3062 - val_loss: 0.2367
# Epoch 47/100
# Epoch 00047: val_loss did not improve
#  - 1s - loss: 0.3043 - val_loss: 0.2600
# Epoch 48/100
# Epoch 00048: val_loss did not improve
#  - 1s - loss: 0.3034 - val_loss: 0.2625
# Epoch 49/100
# Epoch 00049: val_loss did not improve
#  - 1s - loss: 0.3010 - val_loss: 0.2368
# Epoch 50/100
# Epoch 00050: val_loss improved from 0.23667 to 0.23498, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.3000 - val_loss: 0.2350
# Epoch 51/100
# Epoch 00051: val_loss did not improve
#  - 1s - loss: 0.2970 - val_loss: 0.2450
# Epoch 52/100
# Epoch 00052: val_loss improved from 0.23498 to 0.22884, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2956 - val_loss: 0.2288
# Epoch 53/100
# Epoch 00053: val_loss did not improve
#  - 1s - loss: 0.2940 - val_loss: 0.2640
# Epoch 54/100
# Epoch 00054: val_loss improved from 0.22884 to 0.22797, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2919 - val_loss: 0.2280
# Epoch 55/100
# Epoch 00055: val_loss did not improve
#  - 1s - loss: 0.2931 - val_loss: 0.2402
# Epoch 56/100
# Epoch 00056: val_loss did not improve
#  - 1s - loss: 0.2909 - val_loss: 0.2383
# Epoch 57/100
# Epoch 00057: val_loss did not improve
#  - 1s - loss: 0.2889 - val_loss: 0.2318
# Epoch 58/100
# Epoch 00058: val_loss improved from 0.22797 to 0.22633, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2876 - val_loss: 0.2263
# Epoch 59/100
# Epoch 00059: val_loss did not improve
#  - 1s - loss: 0.2863 - val_loss: 0.2422
# Epoch 60/100
# Epoch 00060: val_loss improved from 0.22633 to 0.22476, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2851 - val_loss: 0.2248
# Epoch 61/100
# Epoch 00061: val_loss did not improve
#  - 1s - loss: 0.2844 - val_loss: 0.2749
# Epoch 62/100
# Epoch 00062: val_loss did not improve
#  - 1s - loss: 0.2839 - val_loss: 0.2268
# Epoch 63/100
# Epoch 00063: val_loss did not improve
#  - 1s - loss: 0.2829 - val_loss: 0.2429
# Epoch 64/100
# Epoch 00064: val_loss improved from 0.22476 to 0.22167, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2800 - val_loss: 0.2217
# Epoch 65/100
# Epoch 00065: val_loss improved from 0.22167 to 0.22149, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2804 - val_loss: 0.2215
# Epoch 66/100
# Epoch 00066: val_loss improved from 0.22149 to 0.21662, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2792 - val_loss: 0.2166
# Epoch 67/100
# Epoch 00067: val_loss did not improve
#  - 1s - loss: 0.2760 - val_loss: 0.2300
# Epoch 68/100
# Epoch 00068: val_loss did not improve
#  - 1s - loss: 0.2788 - val_loss: 0.2323
# Epoch 69/100
# Epoch 00069: val_loss did not improve
#  - 1s - loss: 0.2763 - val_loss: 0.2282
# Epoch 70/100
# Epoch 00070: val_loss did not improve
#  - 1s - loss: 0.2742 - val_loss: 0.2206
# Epoch 71/100
# Epoch 00071: val_loss did not improve
#  - 1s - loss: 0.2738 - val_loss: 0.2262
# Epoch 72/100
# Epoch 00072: val_loss did not improve
#  - 2s - loss: 0.2731 - val_loss: 0.2226
# Epoch 73/100
# Epoch 00073: val_loss did not improve
#  - 2s - loss: 0.2738 - val_loss: 0.2371
# Epoch 74/100
# Epoch 00074: val_loss did not improve
#  - 1s - loss: 0.2715 - val_loss: 0.2367
# Epoch 75/100
# Epoch 00075: val_loss did not improve
#  - 1s - loss: 0.2698 - val_loss: 0.2240
# Epoch 76/100
# Epoch 00076: val_loss did not improve
#  - 1s - loss: 0.2703 - val_loss: 0.2190
# Epoch 77/100
# Epoch 00077: val_loss did not improve
#  - 1s - loss: 0.2688 - val_loss: 0.2173
# Epoch 78/100
# Epoch 00078: val_loss did not improve
#  - 1s - loss: 0.2672 - val_loss: 0.2501
# Epoch 79/100
# Epoch 00079: val_loss did not improve
#  - 1s - loss: 0.2675 - val_loss: 0.2351
# Epoch 80/100
# Epoch 00080: val_loss improved from 0.21662 to 0.20573, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2655 - val_loss: 0.2057
# Epoch 81/100
# Epoch 00081: val_loss did not improve
#  - 2s - loss: 0.2656 - val_loss: 0.2150
# Epoch 82/100
# Epoch 00082: val_loss did not improve
#  - 1s - loss: 0.2640 - val_loss: 0.2259
# Epoch 83/100
# Epoch 00083: val_loss did not improve
#  - 1s - loss: 0.2662 - val_loss: 0.2161
# Epoch 84/100
# Epoch 00084: val_loss did not improve
#  - 2s - loss: 0.2617 - val_loss: 0.2095
# Epoch 85/100
# Epoch 00085: val_loss did not improve
#  - 1s - loss: 0.2625 - val_loss: 0.2431
# Epoch 86/100
# Epoch 00086: val_loss did not improve
#  - 1s - loss: 0.2618 - val_loss: 0.2707
# Epoch 87/100
# Epoch 00087: val_loss did not improve
#  - 1s - loss: 0.2600 - val_loss: 0.2318
# Epoch 88/100
# Epoch 00088: val_loss did not improve
#  - 1s - loss: 0.2596 - val_loss: 0.2175
# Epoch 89/100
# Epoch 00089: val_loss improved from 0.20573 to 0.20103, saving model to ./hdf5/only_speed_lstm_simple_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
#  - 1s - loss: 0.2601 - val_loss: 0.2010
# Epoch 90/100
# Epoch 00090: val_loss did not improve
#  - 1s - loss: 0.2584 - val_loss: 0.2127
# Epoch 91/100
# Epoch 00091: val_loss did not improve
#  - 1s - loss: 0.2584 - val_loss: 0.2025
# Epoch 92/100
# Epoch 00092: val_loss did not improve
#  - 2s - loss: 0.2579 - val_loss: 0.2063
# Epoch 93/100
# Epoch 00093: val_loss did not improve
#  - 1s - loss: 0.2567 - val_loss: 0.2163
# Epoch 94/100
# Epoch 00094: val_loss did not improve
#  - 1s - loss: 0.2547 - val_loss: 0.2412
# Epoch 95/100
# Epoch 00095: val_loss did not improve
#  - 1s - loss: 0.2556 - val_loss: 0.2180
# Epoch 96/100
# Epoch 00096: val_loss did not improve
#  - 1s - loss: 0.2537 - val_loss: 0.2242
# Epoch 97/100
# Epoch 00097: val_loss did not improve
#  - 1s - loss: 0.2528 - val_loss: 0.2214
# Epoch 98/100
# Epoch 00098: val_loss did not improve
#  - 1s - loss: 0.2534 - val_loss: 0.2145
# Epoch 99/100
# Epoch 00099: val_loss did not improve
#  - 1s - loss: 0.2525 - val_loss: 0.2026
# Epoch 100/100
# Epoch 00100: val_loss did not improve
#  - 1s - loss: 0.2528 - val_loss: 0.2201
