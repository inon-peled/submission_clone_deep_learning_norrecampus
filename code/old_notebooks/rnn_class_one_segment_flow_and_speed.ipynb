# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
from sklearn.linear_model import LinearRegression
from datetime import timedelta
from keras.callbacks import ModelCheckpoint
import numpy as np
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import pandas as pd
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers.recurrent import LSTM
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras.layers import BatchNormalization
from keras.models import Sequential
from keras import regularizers

from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (16, 10)

# %%
ONE_DAY_LAGS = 288
DATA_PATH = '/mnt/sdc1/inon/norrecampus/data/by_place_5min'
EXAMPLE_PLACE_ID = 'ChIJZaR1M1hSUkYRxP0WkwYYy_k'

THRESHOLD_HIGH_OUTLIER = 110
LOSS = 'mse'
MINI_BATCH_SIZE = 512
NUM_EPOCHS = 100
VALIDATION_SPLIT = 0.2
NUM_LAGS = 12
LSTM_STATE_SIZE = NUM_LAGS
NUM_OUTS_MEAN_SPEED_REGRESSION = 1
SPLIT_DATE = '2015-06-01'

# %%
def split_timestamp(ser):
    return pd\
        .DataFrame(ser)\
        .assign(day_of_week=lambda df: df.index.dayofweek, time_of_day=lambda df: df.index.time)\
        .reset_index()

# %%
def compute_error_statistics_and_plot_15jan2017(errors_df):
    errors_df.drop('error', axis=1)[ONE_DAY_LAGS * 14:ONE_DAY_LAGS * 15].plot()
    plt.legend()
    
    abs_errors = errors_df.error.abs()
    abs_errors_normalized = abs_errors / errors_df.speed_km_hr_true
    return {
        'corr': np.corrcoef(errors_df.speed_km_hr_predicted, errors_df.speed_km_hr_true)[0, 1],
        'mae': np.mean(abs_errors),
        'mape': np.mean(abs_errors_normalized),
        'mse': np.mean(abs_errors ** 2),
        'msne': np.mean(abs_errors_normalized ** 2),
        'rae': np.sum(abs_errors) / np.sum(np.abs(errors_df.speed_km_hr_true - np.mean(errors_df.speed_km_hr_true))),
        'rmse': np.sqrt(np.mean(abs_errors ** 2)),
        'rmsne': np.sqrt(np.mean(abs_errors_normalized ** 2)),
        'r2': max(0, 1 - np.sum(abs_errors ** 2) / np.sum((errors_df.speed_km_hr_true - np.mean(errors_df.speed_km_hr_true)) ** 2))
    }

# %%
class LearnerForFlowAndSpeedOneSegment(object):
    def __init__(self,
                 threshold_speed_outlier,
                 loss,
                 place_id, 
                 mini_batch_size,
                 num_epochs,
                 validation_split,
                 num_lags,
                 lstm_state_size,
                 num_outs,
                 split_date):
        self.model = None
        
        self.threshold_speed_outlier = threshold_speed_outlier
        self.loss = loss
        self.place_id = place_id
        self.mini_batch_size = mini_batch_size
        self.num_epochs = num_epochs
        self.validation_split = validation_split
        self.num_lags = num_lags
        self.lstm_state_size = lstm_state_size
        self.num_outs = num_outs
        self.split_date = split_date
        self.checkpoint_basename = 'simple_lstm_both_%s.best.hdf5' % self.place_id      
    
    def baseline_lr(self):
        X_train_normalized, Y_train_normalized, X_test_normalized, Y_test_normalized = \
            learner._get_train_and_test_inputs()
        trained_lr = LinearRegression(fit_intercept=False)\
            .fit(X_train_normalized.values, Y_train_normalized.values)
        lr_predictions_normalized = trained_lr.predict(X_test_normalized)
        errors_df = self._individual_errors_without_interpolated_values(lr_predictions_normalized)
        return compute_error_statistics_and_plot_15jan2017(errors_df)
        
    def _get_detrend_factors_for_speed(self):
        ser_imp = self._speed_imputation_for_missing_values_and_outliers(self._get_speeds()).speed_km_hr
        df_train_period = ser_imp[lambda df: df.index < self.split_date]
        return df_train_period\
            .groupby([df_train_period.index.dayofweek, df_train_period.index.time])\
            .agg(['mean', 'std'])\
            .reset_index()\
            .rename(columns={'level_0': 'day_of_week', 'level_1': 'time_of_day'})
        
    def detrend(self, ser):
        return pd\
            .merge(left=split_timestamp(ser), 
                   right=self._get_detrend_factors_for_speed(),
                   on=['day_of_week', 'time_of_day'], 
                   how='inner')\
                .assign(speed_normalized=lambda df: (df.speed_km_hr - df['mean']) / df['std'])\
                .set_index('index')\
                .speed_normalized\
                .sort_index()

    def _map_back(self, detrended_series):
        return pd\
            .merge(left=split_timestamp(detrended_series), 
                   right=self._get_detrend_factors_for_speed(),
                   on=['day_of_week', 'time_of_day'], 
                   how='inner')\
            .assign(speed_km_hr=lambda df: (df.speed_normalized * df['std']) + df['mean'])\
            .set_index('index')\
            .speed_km_hr\
            .sort_index()
    
    def _speed_imputation_for_missing_values_and_outliers(self, ser):
        missing_timestamps = pd\
            .date_range(min(ser.index.date), max(ser.index.date) + timedelta(days=1), freq='5T')\
            .difference(ser.index)
        df_with_nans_where_missing = pd.DataFrame(ser)\
            .join(pd.DataFrame(index=missing_timestamps), how='outer')\
            .assign(original_value=lambda df: df.iloc[:, 0])
        return df_with_nans_where_missing\
            .iloc[:, 0]\
            .mask(lambda df: df > self.threshold_speed_outlier)\
            .interpolate()\
            .to_frame()\
            .assign(original_value=df_with_nans_where_missing.original_value)\
            .assign(is_interpolated=lambda df: df.iloc[:, 0] != df.iloc[:, 1])
    
    def _flow_imputation_for_missing_values(self, ser):
        missing_timestamps = pd\
            .date_range(min(ser.index.date), max(ser.index.date) + timedelta(days=1), freq='5T')\
            .difference(ser.index)
        df_with_nans_where_missing = pd.DataFrame(ser)\
            .join(pd.DataFrame(index=missing_timestamps), how='outer')\
            .assign(original_value=lambda df: df.iloc[:, 0])
        df_interpolated = df_with_nans_where_missing\
            .iloc[:, 0]\
            .interpolate()\
            .round()\
            .astype(np.int64)\
            .to_frame()\
            .assign(original_value=df_with_nans_where_missing.original_value)\
            .assign(is_interpolated=lambda df: df.iloc[:, 0] != df.iloc[:, 1])
        assert all(df_interpolated.flow_decile.isin(range(10)))
        return df_interpolated
    
    def _get_flows(self):
        return pd.read_csv(
            os.path.join(DATA_PATH, self.place_id + '.csv'),
            parse_dates=['start_interval_s', 'end_interval_s']\
        )[lambda df: df.start_interval_s >= '2015-01-01']\
        .rename(columns={'start_interval_s': 't', 'flow_bucket': 'flow_decile'})\
        .set_index('t')\
        .flow_decile
    
    def _get_speeds(self):
        return pd.read_csv(
            os.path.join(DATA_PATH, self.place_id + '.csv'),
            parse_dates=['start_interval_s', 'end_interval_s']\
        )[lambda df: df.start_interval_s >= '2015-01-01']\
        .rename(columns={'start_interval_s': 't', 'speed_mean': 'speed_km_hr'})\
        .set_index('t')\
        .speed_km_hr

    def _get_train_and_test_inputs(self):
        def create_lags(ser, column_rename_letter):
            df = pd.concat([ser.shift(x) for x in range(self.num_lags + 1)], axis=1)\
                [self.num_lags:]
            df.columns = [column_rename_letter + str(i) for i in range(self.num_lags + 1)]
            return df
            
        speeds_interpolated_and_detrended = self.detrend(
            self._speed_imputation_for_missing_values_and_outliers(self._get_speeds()).speed_km_hr)
        flows_interpolated = self._flow_imputation_for_missing_values(self._get_flows()).flow_decile
        lags = create_lags(speeds_interpolated_and_detrended, 's').join(create_lags(flows_interpolated, 'f'))
        train = lags[lags.index < self.split_date]
        X_train = train.drop(['s0', 'f0'], axis=1)
        Y_train = train[['s0', 'f0']]
        test = lags[lags.index >= self.split_date]
        X_test = test.drop(['s0', 'f0'], axis=1)
        Y_test = test[['s0', 'f0']]
        return X_train, Y_train, X_test, Y_test

    def _build_model(self):
        self.model = Sequential()
        self.model.add(LSTM(self.lstm_state_size, input_shape=(self.num_lags * 2, 1), return_sequences=False))
        # model.add(Dropout(0.2))
        #model.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.00001)))
        self.model.add(Dense(units=self.num_outs, activation="linear"))  # Linear activation, because speed RESIDUALS can have any sign.
        self.model.compile(loss=self.loss, optimizer="rmsprop")  # TODO: try adam optimizer too, although rmsprop is the default go-to for RNN
    
    def load_best_model_from_disk(self):
        self._build_model()
        self.model.load_weights(self.checkpoint_basename)
    
    def create_and_train_model(self):
        self._build_model()
        X_train, Y_train, _, _ = self._get_train_and_test_inputs()
        self.model.fit(
            np.expand_dims(np.array(X_train.values), 2),
            Y_train.values,
            batch_size=self.mini_batch_size,
            epochs=self.num_epochs,
            validation_split=self.validation_split,
            # checkpoint best model
            callbacks=[ModelCheckpoint(
                self.checkpoint_basename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')],
            verbose=2)
        self.model.load_weights(self.checkpoint_basename)
    
    def predict(self):
        _, _, X_test_normalized, Y_test_normalized = self._get_train_and_test_inputs()
        predictions_normalized = self.model.predict(np.expand_dims(X_test_normalized, 2))
        errors_df = self._individual_errors_without_interpolated_values(predictions_normalized)
        return compute_error_statistics_and_plot_15jan2017(errors_df)
        
    def _impute(self):
        raise NotImplementedError
        
    def _individual_errors_without_interpolated_values(self, predictions_normalized):
        _, _, _, Y_test_normalized = learner._get_train_and_test_inputs()
        ser_Y_test = learner._map_back(Y_test_normalized.iloc[:, 0].squeeze().rename('speed_normalized'))
        ser_predictions = learner._map_back(pd.DataFrame(
            predictions_normalized, index=Y_test_normalized.index, columns=['speed_normalized', 'flow']))
        interpolated_timestamps = self\
            ._speed_imputation_for_missing_values_and_outliers(self._get_speeds())\
            [lambda df: df.is_interpolated]\
            .index
        return ser_Y_test.to_frame()\
            .join(ser_predictions.to_frame(), lsuffix='_true', rsuffix='_predicted')\
            .loc[lambda df: df.index.difference(interpolated_timestamps)]\
            .assign(error=lambda df: df.speed_km_hr_true - df.speed_km_hr_predicted)
                    
learner = LearnerForFlowAndSpeedOneSegment(
    threshold_speed_outlier=THRESHOLD_HIGH_OUTLIER,
    loss=LOSS,
    place_id=EXAMPLE_PLACE_ID, 
    mini_batch_size=MINI_BATCH_SIZE,
    num_epochs=NUM_EPOCHS,
    validation_split=VALIDATION_SPLIT,
    num_lags=NUM_LAGS,
    lstm_state_size=LSTM_STATE_SIZE,
    num_outs=2,
    split_date=SPLIT_DATE)

# %%
learner.create_and_train_model()
# Out:
# Train on 34780 samples, validate on 8696 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 19.08818, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 23.6319 - val_loss: 19.0882
# Epoch 2/100
# Epoch 00001: val_loss improved from 19.08818 to 7.97329, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 13.6208 - val_loss: 7.9733
# Epoch 3/100
# Epoch 00002: val_loss improved from 7.97329 to 4.38611, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 5.9690 - val_loss: 4.3861
# Epoch 4/100
# Epoch 00003: val_loss improved from 4.38611 to 2.43402, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 3.3979 - val_loss: 2.4340
# Epoch 5/100
# Epoch 00004: val_loss improved from 2.43402 to 1.39691, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 1.9787 - val_loss: 1.3969
# Epoch 6/100
# Epoch 00005: val_loss improved from 1.39691 to 0.93163, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 1.2532 - val_loss: 0.9316
# Epoch 7/100
# Epoch 00006: val_loss improved from 0.93163 to 0.79434, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.9511 - val_loss: 0.7943
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.79434 to 0.72513, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.8626 - val_loss: 0.7251
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 3s - loss: 0.8454 - val_loss: 0.7281
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.72513 to 0.71317, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.8341 - val_loss: 0.7132
# Epoch 11/100
# Epoch 00010: val_loss improved from 0.71317 to 0.70440, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.8271 - val_loss: 0.7044
# Epoch 12/100
# Epoch 00011: val_loss improved from 0.70440 to 0.70183, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.8182 - val_loss: 0.7018
# Epoch 13/100
# Epoch 00012: val_loss improved from 0.70183 to 0.69430, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.8100 - val_loss: 0.6943
# Epoch 14/100
# Epoch 00013: val_loss improved from 0.69430 to 0.68089, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7994 - val_loss: 0.6809
# Epoch 15/100
# Epoch 00014: val_loss improved from 0.68089 to 0.66950, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7875 - val_loss: 0.6695
# Epoch 16/100
# Epoch 00015: val_loss improved from 0.66950 to 0.65367, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7747 - val_loss: 0.6537
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 3s - loss: 0.7668 - val_loss: 0.6626
# Epoch 18/100
# Epoch 00017: val_loss improved from 0.65367 to 0.62898, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7479 - val_loss: 0.6290
# Epoch 19/100
# Epoch 00018: val_loss improved from 0.62898 to 0.61783, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7400 - val_loss: 0.6178
# Epoch 20/100
# Epoch 00019: val_loss improved from 0.61783 to 0.60951, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7236 - val_loss: 0.6095
# Epoch 21/100
# Epoch 00020: val_loss improved from 0.60951 to 0.59366, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7151 - val_loss: 0.5937
# Epoch 22/100
# Epoch 00021: val_loss improved from 0.59366 to 0.58843, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.7007 - val_loss: 0.5884
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 3s - loss: 0.6910 - val_loss: 0.5969
# Epoch 24/100
# Epoch 00023: val_loss improved from 0.58843 to 0.57323, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.6846 - val_loss: 0.5732
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 3s - loss: 0.6711 - val_loss: 0.5787
# Epoch 26/100
# Epoch 00025: val_loss improved from 0.57323 to 0.54884, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.6625 - val_loss: 0.5488
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 3s - loss: 0.6520 - val_loss: 0.5506
# Epoch 28/100
# Epoch 00027: val_loss improved from 0.54884 to 0.53416, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.6442 - val_loss: 0.5342
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 3s - loss: 0.6377 - val_loss: 0.5342
# Epoch 30/100
# Epoch 00029: val_loss improved from 0.53416 to 0.52265, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.6290 - val_loss: 0.5226
# Epoch 31/100
# Epoch 00030: val_loss improved from 0.52265 to 0.51873, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.6247 - val_loss: 0.5187
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 3s - loss: 0.6155 - val_loss: 0.5596
# Epoch 33/100
# Epoch 00032: val_loss improved from 0.51873 to 0.50477, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.6097 - val_loss: 0.5048
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 3s - loss: 0.6054 - val_loss: 0.5175
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 3s - loss: 0.6014 - val_loss: 0.5267
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 3s - loss: 0.5925 - val_loss: 0.5058
# Epoch 37/100
# Epoch 00036: val_loss improved from 0.50477 to 0.49747, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5906 - val_loss: 0.4975
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 3s - loss: 0.5862 - val_loss: 0.5152
# Epoch 39/100
# Epoch 00038: val_loss improved from 0.49747 to 0.48189, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5828 - val_loss: 0.4819
# Epoch 40/100
# Epoch 00039: val_loss improved from 0.48189 to 0.48027, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5776 - val_loss: 0.4803
# Epoch 41/100
# Epoch 00040: val_loss improved from 0.48027 to 0.47727, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5745 - val_loss: 0.4773
# Epoch 42/100
# Epoch 00041: val_loss improved from 0.47727 to 0.47645, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5715 - val_loss: 0.4764
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 3s - loss: 0.5677 - val_loss: 0.4848
# Epoch 44/100
# Epoch 00043: val_loss improved from 0.47645 to 0.47106, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5639 - val_loss: 0.4711
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 3s - loss: 0.5590 - val_loss: 0.5466
# Epoch 46/100
# Epoch 00045: val_loss improved from 0.47106 to 0.45834, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5576 - val_loss: 0.4583
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 3s - loss: 0.5552 - val_loss: 0.5073
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 3s - loss: 0.5534 - val_loss: 0.4613
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 3s - loss: 0.5449 - val_loss: 0.4588
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 3s - loss: 0.5446 - val_loss: 0.4589
# Epoch 51/100
# Epoch 00050: val_loss improved from 0.45834 to 0.44281, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5384 - val_loss: 0.4428
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 3s - loss: 0.5377 - val_loss: 0.5039
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 3s - loss: 0.5335 - val_loss: 0.5096
# Epoch 54/100
# Epoch 00053: val_loss improved from 0.44281 to 0.43394, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5312 - val_loss: 0.4339
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 3s - loss: 0.5274 - val_loss: 0.4566
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 3s - loss: 0.5227 - val_loss: 0.5099
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 3s - loss: 0.5218 - val_loss: 0.4353
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 3s - loss: 0.5157 - val_loss: 0.4407
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 3s - loss: 0.5142 - val_loss: 0.4427
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 3s - loss: 0.5138 - val_loss: 0.4416
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 3s - loss: 0.5084 - val_loss: 0.4766
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 3s - loss: 0.5074 - val_loss: 0.4632
# Epoch 63/100
# Epoch 00062: val_loss improved from 0.43394 to 0.42443, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.5016 - val_loss: 0.4244
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 3s - loss: 0.5008 - val_loss: 0.4650
# Epoch 65/100
# Epoch 00064: val_loss improved from 0.42443 to 0.40032, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4943 - val_loss: 0.4003
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 3s - loss: 0.4951 - val_loss: 0.4448
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 3s - loss: 0.4902 - val_loss: 0.4345
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 3s - loss: 0.4877 - val_loss: 0.4165
# Epoch 69/100
# Epoch 00068: val_loss improved from 0.40032 to 0.39877, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4841 - val_loss: 0.3988
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 3s - loss: 0.4815 - val_loss: 0.4498
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 3s - loss: 0.4776 - val_loss: 0.4132
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 3s - loss: 0.4764 - val_loss: 0.4008
# Epoch 73/100
# Epoch 00072: val_loss improved from 0.39877 to 0.39319, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4717 - val_loss: 0.3932
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 3s - loss: 0.4711 - val_loss: 0.4037
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 3s - loss: 0.4675 - val_loss: 0.4018
# Epoch 76/100
# Epoch 00075: val_loss improved from 0.39319 to 0.38821, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4674 - val_loss: 0.3882
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 3s - loss: 0.4633 - val_loss: 0.4528
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 3s - loss: 0.4612 - val_loss: 0.4002
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 3s - loss: 0.4586 - val_loss: 0.3913
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 3s - loss: 0.4534 - val_loss: 0.3971
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 3s - loss: 0.4549 - val_loss: 0.4027
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 3s - loss: 0.4503 - val_loss: 0.3917
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 3s - loss: 0.4472 - val_loss: 0.4180
# Epoch 84/100
# Epoch 00083: val_loss improved from 0.38821 to 0.36185, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4484 - val_loss: 0.3619
# Epoch 85/100
# Epoch 00084: val_loss improved from 0.36185 to 0.35932, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4472 - val_loss: 0.3593
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 3s - loss: 0.4422 - val_loss: 0.3781
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 3s - loss: 0.4424 - val_loss: 0.4182
# Epoch 88/100
# Epoch 00087: val_loss improved from 0.35932 to 0.35136, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4380 - val_loss: 0.3514
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 3s - loss: 0.4373 - val_loss: 0.3776
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 3s - loss: 0.4364 - val_loss: 0.4066
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 3s - loss: 0.4326 - val_loss: 0.3529
# Epoch 92/100
# Epoch 00091: val_loss improved from 0.35136 to 0.34842, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4360 - val_loss: 0.3484
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 3s - loss: 0.4323 - val_loss: 0.4022
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 3s - loss: 0.4294 - val_loss: 0.3967
# Epoch 95/100
# Epoch 00094: val_loss improved from 0.34842 to 0.34675, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4298 - val_loss: 0.3468
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 3s - loss: 0.4230 - val_loss: 0.4324
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 3s - loss: 0.4277 - val_loss: 0.3518
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 3s - loss: 0.4222 - val_loss: 0.3509
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 3s - loss: 0.4223 - val_loss: 0.3579
# Epoch 100/100
# Epoch 00099: val_loss improved from 0.34675 to 0.34487, saving model to simple_lstm_both_ChIJZaR1M1hSUkYRxP0WkwYYy_k.best.hdf5
# 3s - loss: 0.4187 - val_loss: 0.3449

# %%
learner.load_best_model_from_disk()
learner.predict()
# Out:
# {'corr': 0.7841126683649271,
#  'mae': 2.7127417838269037,
#  'mape': inf,
#  'mse': 20.915945315782331,
#  'msne': inf,
#  'r2': 0.60645408669969203,
#  'rae': 0.51970919868929843,
#  'rmse': 4.5733953815280755,
#  'rmsne': inf}

# %%
learner.baseline_lr()
# Out:
# {'corr': 0.85887030392589636,
#  'mae': 1.9790370388139009,
#  'mape': inf,
#  'mse': 14.369192343355737,
#  'msne': inf,
#  'r2': 0.72963512579626322,
#  'rae': 0.37914546815711342,
#  'rmse': 3.7906717535755767,
#  'rmsne': inf}
